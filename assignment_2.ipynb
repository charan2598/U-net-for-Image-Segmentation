# %% [markdown]
# ### Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

import torch.optim as optim

import os

from PIL import Image, ImageOps

import random

#import any other library you need below this line
import math

# %% [markdown]
# ### Loading data
#
# Upload the data in zip format to Colab. Then run the cell below.

# %%
#!unzip data.zip

# %% [markdown]
# ### Defining the Dataset Class

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
class Cell_data(Dataset):
    def __init__(self, data_dir, size, train = True, train_test_split = 0.8, augment_data = True, transform = None):
        ##########################inputs##################################
        #data_dir(string) - directory of the data#########################
        #size(int) - size of the images you want to use###################
        #train(boolean) - train data or test data#########################
        #train_test_split(float) - the portion of the data for training###
        #augment_data(boolean) - use data augmentation or not#############
        super(Cell_data, self).__init__()
        # todo
        #initialize the data class
        self.image_files = os.listdir(data_dir+"/scans")
        self.transform = transform
        train_test_split = math.floor(train_test_split*len(self.image_files))

        self.augmented_images_dir = data_dir+"/augmented_data"
        if not os.path.exists(self.augmented_images_dir):
            os.mkdir(self.augmented_images_dir)

        random.shuffle(self.image_files)
        if train == True:
            train_image_files = self.augmented_images_dir+"/train"
            os.mkdir(train_image_files)
            os.mkdir(train_image_files+"/scans")
            os.mkdir(train_image_files+"/labels")
            self.final_images_dir = train_image_files
            dataset_for_augmentation = self.image_files[:train_test_split]
        else:
            test_image_files = self.augmented_images_dir+"/test"
            os.mkdir(test_image_files)
            os.mkdir(test_image_files+"/scans")
            os.mkdir(test_image_files+"/labels")
            self.final_images_dir = test_image_files
            dataset_for_augmentation = self.image_files[train_test_split:]

        image_count=1
        for image in dataset_for_augmentation:
            scan_image = Image.open(data_dir+"/scans/"+image)
            scan_image = scan_image.resize((size, size))
            label_image = Image.open(data_dir+"/labels/"+image)
            label_image = label_image.resize((size, size))
            #data augmentation part
            if augment_data:
                augment_mode = np.random.randint(0, 4) ############## Ignoring the case of zoom and gamma correction so reduced range from 5 to 4
                if augment_mode == 0 or augment_mode == 1:
                    #todo 
                    #flip image vertically
                    augmented_scan_image_1 = TF.vflip(scan_image)
                    augmented_label_image_1 = TF.vflip(label_image)

                    #todo
                    #flip image horizontally
                    augmented_scan_image_2 = TF.hflip(scan_image)
                    augmented_label_image_2 = TF.hflip(label_image)
                elif augment_mode == 2 or augment_mode == 3:
                    #todo
                    #rotate image
                    angle = random.randint(-30, 30)
                    augmented_scan_image_1 = TF.rotate(scan_image, angle)
                    augmented_label_image_1 = TF.rotate(label_image, angle)

                    #Gamma correction
                    gamma = random.randrange(3,8)/10
                    augmented_scan_image_2 = TF.adjust_gamma(scan_image, gamma)
                    augmented_label_image_2 = label_image
                else: # Not used for now
                    #todo
                    #zoom image
                    zoom_size = random.randint(int(self.size*0.75), self.size)
                    augmented_scan_image_1 = TF.center_crop(scan_image, zoom_size)
                    augmented_label_image_1 = TF.center_crop(label_image, zoom_size)
                
                #write the files to the augmented data location
                scan_image.save(self.final_images_dir+"/scans/"+str(image_count)+".bmp") # original image is saved as 1.bmp
                augmented_scan_image_1.save(self.final_images_dir+"/scans/"+str(image_count+1)+".bmp") # augmented image is saved as 2.jpg
                augmented_scan_image_2.save(self.final_images_dir+"/scans/"+str(image_count+2)+".bmp") # augmented image is saved as 3.jpg
                label_image.save(self.final_images_dir+"/labels/"+str(image_count)+".bmp") # original label is saved as 1.bmp
                augmented_label_image_1.save(self.final_images_dir+"/labels/"+str(image_count+1)+".bmp") # augmented label is saved as 2.jpg
                augmented_label_image_2.save(self.final_images_dir+"/labels/"+str(image_count+2)+".bmp") # augmented label is saved as 3.jpg
                image_count+=3
        
        self.dataset = os.listdir(self.final_images_dir+"/scans")


    def __getitem__(self, idx):
        # todo
        #load image and mask from index idx of your data
        filename = self.dataset[idx]
        scan_image = Image.open(self.final_images_dir+"/scans/"+filename)
        label_image = Image.open(self.final_images_dir+"/labels/"+filename)
        #todo
        #return image and mask in tensors

        return self.transform(scan_image), torch.ceil(self.transform(label_image))

    def __len__(self):
        return len(self.dataset)

# %% [markdown]
# ### Define the Model
# 1. Define the Convolution blocks
# 2. Define the down path
# 3. Define the up path
# 4. combine the down and up path to get the final model

# %%
TEMP = False
class twoConvBlock(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(twoConvBlock, self).__init__()
        #todo
        #initialize the block
        self.conv_layer1 = nn.Conv2d(input_channels, output_channels, kernel_size=3, stride=1)
        self.conv_layer2 = nn.Conv2d(output_channels, output_channels, kernel_size=3, stride=1)
        self.batch_norm_layer = nn.BatchNorm2d(output_channels)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.conv_layer1(image)
        image = F.relu(image)
        image = self.conv_layer2(image)
        image = self.batch_norm_layer(image)
        image = F.relu(image)
        return image

class downStep(nn.Module):
    def __init__(self):
        super(downStep, self).__init__()
        #todo
        #initialize the down path
        self.max_pool_layer = nn.MaxPool2d(kernel_size=2,stride=2)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.max_pool_layer(image)
        return image

class upStep(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(upStep, self).__init__()
        #todo
        #initialize the up path
        self.up_sampling_layer = nn.ConvTranspose2d(input_channels, output_channels, kernel_size=2, stride=2)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.up_sampling_layer(image)
        return image

def crop_tensor(input_copy, ideal_size):
    h_delta = (input_copy.shape[2]-ideal_size.shape[2]) // 2
    w_delta = (input_copy.shape[3]-ideal_size.shape[3]) // 2
    return input_copy[:,:,h_delta:input_copy.shape[2]-h_delta, w_delta:input_copy.shape[3]-w_delta]

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        #todo
        #initialize the complete model
        self.conv1 = twoConvBlock(1, 64)
        self.conv2 = twoConvBlock(64, 128)
        self.conv3 = twoConvBlock(128, 256)
        self.conv4 = twoConvBlock(256, 512)
        self.conv5 = twoConvBlock(512, 1024)
        self.conv6 = twoConvBlock(1024, 512)
        self.conv7 = twoConvBlock(512, 256)
        self.conv8 = twoConvBlock(256, 128)
        self.conv9 = twoConvBlock(128, 64)
        self.conv10 = nn.Conv2d(in_channels=64, out_channels=2, kernel_size=1, stride=1)
        self.down_step = downStep()
        self.up_step1 = upStep(1024, 512)
        self.up_step2 = upStep(512, 256)
        self.up_step3 = upStep(256,128)
        self.up_step4 = upStep(128,64)

    def forward(self, input):
        #todo
        #implement the forward path
        conv1_op = self.conv1(input)
        down_sampled = self.down_step(conv1_op)
        conv2_op = self.conv2(down_sampled)
        down_sampled = self.down_step(conv2_op)
        conv3_op = self.conv3(down_sampled)
        down_sampled = self.down_step(conv3_op)
        conv4_op = self.conv4(down_sampled)
        down_sampled = self.down_step(conv4_op)
        conv5_op = self.conv5(down_sampled)
        up_sampled = self.up_step1(conv5_op)
        # Conv 6 output is the one below
        conv_op = self.conv6(torch.cat(tensors=(up_sampled, crop_tensor(conv4_op, up_sampled)), dim=1))
        up_sampled = self.up_step2(conv_op)
        conv_op = self.conv7(torch.cat(tensors=(up_sampled, crop_tensor(conv3_op, up_sampled)), dim=1))
        up_sampled = self.up_step3(conv_op)
        conv_op = self.conv8(torch.cat(tensors=(up_sampled, crop_tensor(conv2_op, up_sampled)), dim=1))
        up_sampled = self.up_step4(conv_op)
        conv_op = self.conv9(torch.cat(tensors=(up_sampled, crop_tensor(conv1_op, up_sampled)), dim=1))
        conv_op = self.conv10(conv_op)

        return conv_op

# %% [markdown]
# ### Training

# %%
#Paramteres

#learning rate
lr = 1e-2

#number of training epochs
epoch_n = 20

#input image-mask size
image_size = 572
#root directory of project
root_dir = os.getcwd()

#training batch size
batch_size = 2

#use checkpoint model for training
load = True

#use GPU for training
gpu = True

data_dir = os.path.join(root_dir, 'data/cells')

trainset = Cell_data(data_dir = data_dir, size = image_size, transform = transform)
trainloader = DataLoader(trainset, batch_size = batch_size, shuffle=True)

testset = Cell_data(data_dir = data_dir, size = image_size, train = False, transform = transform)
testloader = DataLoader(testset, batch_size = batch_size)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = UNet().to(device)

if load:
    print('loading model')
    model.load_state_dict(torch.load('checkpoint.pt'))

criterion = nn.CrossEntropyLoss()

#optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.0005)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.99, weight_decay=0.0005)
# Out:
# loading model

# %%
model.train()
for e in range(epoch_n):
    epoch_loss = 0
    model.train()
    for i, data in enumerate(trainloader):
        image, label = data

        image = image.to(device)
        label = label.long().to(device)

        pred = model(image)

        crop_x = (label.shape[2] - pred.shape[2]) // 2
        crop_y = (label.shape[3] - pred.shape[3]) // 2

        label = label[:, :, crop_x: label.shape[2] - crop_x, crop_y: label.shape[3] - crop_y]

        pred = torch.squeeze(pred,1)
        label = torch.squeeze(label,1)
    
        loss = criterion(pred, label)

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()

        epoch_loss += loss.item()

        print('batch %d --- Loss: %.4f' % (i, loss.item() / batch_size)) ############################# Uncomment this later
    print('Epoch %d / %d --- Loss: %.4f' % (e + 1, epoch_n, epoch_loss / trainset.__len__()))

    torch.save(model.state_dict(), 'checkpoint.pt') # Commented this out for now ##############################

    model.eval()

    total = 0
    correct = 0
    total_loss = 0

    with torch.no_grad():
        for i, data in enumerate(testloader):
            image, label = data

            #image = image.unsqueeze(1).to(device)
            image = image.to(device)
            label = label.long().to(device)

            pred = model(image)
            crop_x = (label.shape[2] - pred.shape[2]) // 2
            crop_y = (label.shape[3] - pred.shape[3]) // 2

            label = label[:, :, crop_x: label.shape[2] - crop_x, crop_y: label.shape[3] - crop_y]
            
            pred = torch.squeeze(pred,1)
            label = torch.squeeze(label,1)

            loss = criterion(pred, label)
            total_loss += loss.item()

            _, pred_labels = torch.max(pred, dim = 1)

            total += label.shape[0] * label.shape[1] * label.shape[2]
            correct += (pred_labels == label).sum().item()

        print('Accuracy: %.4f ---- Loss: %.4f' % (correct / total, total_loss / testset.__len__()))
# Out:
# batch 0 --- Loss: 0.2451
# batch 1 --- Loss: 0.1508
# batch 2 --- Loss: 0.1335
# batch 3 --- Loss: 0.2188
# batch 4 --- Loss: 0.2508
# batch 5 --- Loss: 0.2626
# batch 6 --- Loss: 0.2755
# batch 7 --- Loss: 0.1964
# batch 8 --- Loss: 0.2686
# batch 9 --- Loss: 0.1597
# batch 10 --- Loss: 0.1833
# batch 11 --- Loss: 0.1875
# batch 12 --- Loss: 0.1393
# batch 13 --- Loss: 0.3032
# batch 14 --- Loss: 0.1891
# batch 15 --- Loss: 0.2151
# batch 16 --- Loss: 0.1821
# batch 17 --- Loss: 0.1628
# batch 18 --- Loss: 0.1629
# batch 19 --- Loss: 0.1356
# batch 20 --- Loss: 0.1612
# batch 21 --- Loss: 0.1351
# batch 22 --- Loss: 0.2037
# batch 23 --- Loss: 0.1904
# batch 24 --- Loss: 0.3668
# batch 25 --- Loss: 0.3464
# batch 26 --- Loss: 0.2455
# batch 27 --- Loss: 0.2493
# batch 28 --- Loss: 0.1397
# batch 29 --- Loss: 0.2243
# batch 30 --- Loss: 0.2662
# batch 31 --- Loss: 0.2413
# batch 32 --- Loss: 0.3173
# batch 33 --- Loss: 0.1779
# batch 34 --- Loss: 0.2189
# batch 35 --- Loss: 0.1821
# batch 36 --- Loss: 0.1656
# batch 37 --- Loss: 0.1809
# batch 38 --- Loss: 0.1496
# batch 39 --- Loss: 0.1485
# batch 40 --- Loss: 0.1847
# batch 41 --- Loss: 0.1877
# batch 42 --- Loss: 0.1630
# batch 43 --- Loss: 0.3113
# batch 44 --- Loss: 0.2829
# Epoch 1 / 20 --- Loss: 0.2103
# Accuracy: 0.8183 ---- Loss: 0.2079
# batch 0 --- Loss: 0.4324
# batch 1 --- Loss: 0.1428
# batch 2 --- Loss: 0.2543
# batch 3 --- Loss: 0.2037
# batch 4 --- Loss: 0.1955
# batch 5 --- Loss: 0.2915
# batch 6 --- Loss: 0.2244
# batch 7 --- Loss: 0.1341
# batch 8 --- Loss: 0.1524
# batch 9 --- Loss: 0.1449
# batch 10 --- Loss: 0.1545
# batch 11 --- Loss: 0.3419
# batch 12 --- Loss: 0.3509
# batch 13 --- Loss: 0.3392
# batch 14 --- Loss: 0.1971
# batch 15 --- Loss: 0.1604
# batch 16 --- Loss: 0.2368
# batch 17 --- Loss: 0.1857
# batch 18 --- Loss: 0.2226
# batch 19 --- Loss: 0.1476
# batch 20 --- Loss: 0.2592
# batch 21 --- Loss: 0.1705
# batch 22 --- Loss: 0.1755
# batch 23 --- Loss: 0.1945
# batch 24 --- Loss: 0.1931
# batch 25 --- Loss: 0.3057
# batch 26 --- Loss: 0.2838
# batch 27 --- Loss: 0.1720
# batch 28 --- Loss: 0.1696
# batch 29 --- Loss: 0.1722
# batch 30 --- Loss: 0.2019
# batch 31 --- Loss: 0.1532
# batch 32 --- Loss: 0.1868
# batch 33 --- Loss: 0.1848
# batch 34 --- Loss: 0.1983
# batch 35 --- Loss: 0.1669
# batch 36 --- Loss: 0.1523
# batch 37 --- Loss: 0.1832
# batch 38 --- Loss: 0.2099
# batch 39 --- Loss: 0.2901
# batch 40 --- Loss: 0.1190
# batch 41 --- Loss: 0.1782
# batch 42 --- Loss: 0.1538
# batch 43 --- Loss: 0.2167
# batch 44 --- Loss: 0.1520
# Epoch 2 / 20 --- Loss: 0.2079
# Accuracy: 0.8086 ---- Loss: 0.2312
# batch 0 --- Loss: 0.1601
# batch 1 --- Loss: 0.1641
# batch 2 --- Loss: 0.2351
# batch 3 --- Loss: 0.1824
# batch 4 --- Loss: 0.1555
# batch 5 --- Loss: 0.1145
# batch 6 --- Loss: 0.1931
# batch 7 --- Loss: 0.1794
# batch 8 --- Loss: 0.1504
# batch 9 --- Loss: 0.1859
# batch 10 --- Loss: 0.2780
# batch 11 --- Loss: 0.1490
# batch 12 --- Loss: 0.4367
# batch 13 --- Loss: 0.1884
# batch 14 --- Loss: 0.2035
# batch 15 --- Loss: 0.1541
# batch 16 --- Loss: 0.1954
# batch 17 --- Loss: 0.1893
# batch 18 --- Loss: 0.1514
# batch 19 --- Loss: 0.3122
# batch 20 --- Loss: 0.3272
# batch 21 --- Loss: 0.3036
# batch 22 --- Loss: 0.1262
# batch 23 --- Loss: 0.1452
# batch 24 --- Loss: 0.2785
# batch 25 --- Loss: 0.1230
# batch 26 --- Loss: 0.2921
# batch 27 --- Loss: 0.2138
# batch 28 --- Loss: 0.1350
# batch 29 --- Loss: 0.2257
# batch 30 --- Loss: 0.3181
# batch 31 --- Loss: 0.1260
# batch 32 --- Loss: 0.2018
# batch 33 --- Loss: 0.1506
# batch 34 --- Loss: 0.2320
# batch 35 --- Loss: 0.1950
# batch 36 --- Loss: 0.1438
# batch 37 --- Loss: 0.2222
# batch 38 --- Loss: 0.1795
# batch 39 --- Loss: 0.3290
# batch 40 --- Loss: 0.1160
# batch 41 --- Loss: 0.1369
# batch 42 --- Loss: 0.1724
# batch 43 --- Loss: 0.3011
# batch 44 --- Loss: 0.3085
# Epoch 3 / 20 --- Loss: 0.2063
# Accuracy: 0.8011 ---- Loss: 0.2186
# batch 0 --- Loss: 0.1436
# batch 1 --- Loss: 0.1714
# batch 2 --- Loss: 0.2038
# batch 3 --- Loss: 0.1514
# batch 4 --- Loss: 0.2828
# batch 5 --- Loss: 0.1917
# batch 6 --- Loss: 0.1794
# batch 7 --- Loss: 0.1509
# batch 8 --- Loss: 0.1365
# batch 9 --- Loss: 0.1824
# batch 10 --- Loss: 0.2079
# batch 11 --- Loss: 0.2353
# batch 12 --- Loss: 0.2075
# batch 13 --- Loss: 0.1759
# batch 14 --- Loss: 0.1591
# batch 15 --- Loss: 0.2888
# batch 16 --- Loss: 0.2035
# batch 17 --- Loss: 0.1491
# batch 18 --- Loss: 0.2248
# batch 19 --- Loss: 0.1309
# batch 20 --- Loss: 0.2000
# batch 21 --- Loss: 0.1635
# batch 22 --- Loss: 0.1244
# batch 23 --- Loss: 0.1449
# batch 24 --- Loss: 0.2663
# batch 25 --- Loss: 0.1134
# batch 26 --- Loss: 0.3364
# batch 27 --- Loss: 0.1682
# batch 28 --- Loss: 0.1851
# batch 29 --- Loss: 0.2104
# batch 30 --- Loss: 0.1615
# batch 31 --- Loss: 0.3184
# batch 32 --- Loss: 0.1358
# batch 33 --- Loss: 0.1895
# batch 34 --- Loss: 0.2040
# batch 35 --- Loss: 0.1595
# batch 36 --- Loss: 0.3279
# batch 37 --- Loss: 0.1596
# batch 38 --- Loss: 0.4370
# batch 39 --- Loss: 0.2539
# batch 40 --- Loss: 0.3668
# batch 41 --- Loss: 0.2774
# batch 42 --- Loss: 0.1628
# batch 43 --- Loss: 0.1430
# batch 44 --- Loss: 0.1357
# Epoch 4 / 20 --- Loss: 0.2027
# Accuracy: 0.8116 ---- Loss: 0.2177
# batch 0 --- Loss: 0.2696
# batch 1 --- Loss: 0.1644
# batch 2 --- Loss: 0.3251
# batch 3 --- Loss: 0.1374
# batch 4 --- Loss: 0.1512
# batch 5 --- Loss: 0.1718
# batch 6 --- Loss: 0.1937
# batch 7 --- Loss: 0.1686
# batch 8 --- Loss: 0.1944
# batch 9 --- Loss: 0.1858
# batch 10 --- Loss: 0.3313
# batch 11 --- Loss: 0.1934
# batch 12 --- Loss: 0.2362
# batch 13 --- Loss: 0.1600
# batch 14 --- Loss: 0.1436
# batch 15 --- Loss: 0.2094
# batch 16 --- Loss: 0.1722
# batch 17 --- Loss: 0.2956
# batch 18 --- Loss: 0.1459
# batch 19 --- Loss: 0.1391
# batch 20 --- Loss: 0.3229
# batch 21 --- Loss: 0.1575
# batch 22 --- Loss: 0.1621
# batch 23 --- Loss: 0.2717
# batch 24 --- Loss: 0.1636
# batch 25 --- Loss: 0.1405
# batch 26 --- Loss: 0.1546
# batch 27 --- Loss: 0.1720
# batch 28 --- Loss: 0.2428
# batch 29 --- Loss: 0.1539
# batch 30 --- Loss: 0.1402
# batch 31 --- Loss: 0.1543
# batch 32 --- Loss: 0.3193
# batch 33 --- Loss: 0.2549
# batch 34 --- Loss: 0.1375
# batch 35 --- Loss: 0.2479
# batch 36 --- Loss: 0.1934
# batch 37 --- Loss: 0.1848
# batch 38 --- Loss: 0.1625
# batch 39 --- Loss: 0.1907
# batch 40 --- Loss: 0.1822
# batch 41 --- Loss: 0.2541
# batch 42 --- Loss: 0.2019
# batch 43 --- Loss: 0.2443
# batch 44 --- Loss: 0.1882
# Epoch 5 / 20 --- Loss: 0.1997
# Accuracy: 0.8113 ---- Loss: 0.2187
# batch 0 --- Loss: 0.1935
# batch 1 --- Loss: 0.1500
# batch 2 --- Loss: 0.2637
# batch 3 --- Loss: 0.1801
# batch 4 --- Loss: 0.1963
# batch 5 --- Loss: 0.1653
# batch 6 --- Loss: 0.1606
# batch 7 --- Loss: 0.1349
# batch 8 --- Loss: 0.1326
# batch 9 --- Loss: 0.1498
# batch 10 --- Loss: 0.1684
# batch 11 --- Loss: 0.1562
# batch 12 --- Loss: 0.2798
# batch 13 --- Loss: 0.1323
# batch 14 --- Loss: 0.2382
# batch 15 --- Loss: 0.2864
# batch 16 --- Loss: 0.2228
# batch 17 --- Loss: 0.1887
# batch 18 --- Loss: 0.2847
# batch 19 --- Loss: 0.1800
# batch 20 --- Loss: 0.1719
# batch 21 --- Loss: 0.1242
# batch 22 --- Loss: 0.1665
# batch 23 --- Loss: 0.2695
# batch 24 --- Loss: 0.1748
# batch 25 --- Loss: 0.1678
# batch 26 --- Loss: 0.2587
# batch 27 --- Loss: 0.2778
# batch 28 --- Loss: 0.1765
# batch 29 --- Loss: 0.1652
# batch 30 --- Loss: 0.2382
# batch 31 --- Loss: 0.3132
# batch 32 --- Loss: 0.1568
# batch 33 --- Loss: 0.2201
# batch 34 --- Loss: 0.1638
# batch 35 --- Loss: 0.2008
# batch 36 --- Loss: 0.2435
# batch 37 --- Loss: 0.1853
# batch 38 --- Loss: 0.3035
# batch 39 --- Loss: 0.2184
# batch 40 --- Loss: 0.1187
# batch 41 --- Loss: 0.1757
# batch 42 --- Loss: 0.2748
# batch 43 --- Loss: 0.1538
# batch 44 --- Loss: 0.2211
# Epoch 6 / 20 --- Loss: 0.2001
# Accuracy: 0.7919 ---- Loss: 0.2371
# batch 0 --- Loss: 0.1475
# batch 1 --- Loss: 0.1280
# batch 2 --- Loss: 0.2060
# batch 3 --- Loss: 0.2577
# batch 4 --- Loss: 0.2378
# batch 5 --- Loss: 0.3015
# batch 6 --- Loss: 0.2084
# batch 7 --- Loss: 0.1300
# batch 8 --- Loss: 0.1594
# batch 9 --- Loss: 0.2777
# batch 10 --- Loss: 0.1617
# batch 11 --- Loss: 0.1185
# batch 12 --- Loss: 0.1893
# batch 13 --- Loss: 0.2041
# batch 14 --- Loss: 0.1625
# batch 15 --- Loss: 0.2238
# batch 16 --- Loss: 0.3509
# batch 17 --- Loss: 0.2542
# batch 18 --- Loss: 0.1563
# batch 19 --- Loss: 0.1695
# batch 20 --- Loss: 0.2778
# batch 21 --- Loss: 0.1501
# batch 22 --- Loss: 0.1903
# batch 23 --- Loss: 0.2890
# batch 24 --- Loss: 0.1704
# batch 25 --- Loss: 0.1266
# batch 26 --- Loss: 0.2258
# batch 27 --- Loss: 0.2663
# batch 28 --- Loss: 0.1892
# batch 29 --- Loss: 0.1596
# batch 30 --- Loss: 0.1228
# batch 31 --- Loss: 0.2577
# batch 32 --- Loss: 0.1555
# batch 33 --- Loss: 0.2008
# batch 34 --- Loss: 0.1587
# batch 35 --- Loss: 0.1421
# batch 36 --- Loss: 0.2727
# batch 37 --- Loss: 0.1424
# batch 38 --- Loss: 0.1972
# batch 39 --- Loss: 0.1780
# batch 40 --- Loss: 0.2777
# batch 41 --- Loss: 0.1806
# batch 42 --- Loss: 0.1541
# batch 43 --- Loss: 0.1912
# batch 44 --- Loss: 0.1897
# Epoch 7 / 20 --- Loss: 0.1980
# Accuracy: 0.7840 ---- Loss: 0.2327
# batch 0 --- Loss: 0.2026
# batch 1 --- Loss: 0.2493
# batch 2 --- Loss: 0.1814
# batch 3 --- Loss: 0.1516
# batch 4 --- Loss: 0.1633
# batch 5 --- Loss: 0.1249
# batch 6 --- Loss: 0.3027
# batch 7 --- Loss: 0.1352
# batch 8 --- Loss: 0.2245
# batch 9 --- Loss: 0.2510
# batch 10 --- Loss: 0.2069
# batch 11 --- Loss: 0.1568
# batch 12 --- Loss: 0.2487
# batch 13 --- Loss: 0.2755
# batch 14 --- Loss: 0.2718
# batch 15 --- Loss: 0.1681
# batch 16 --- Loss: 0.1547
# batch 17 --- Loss: 0.2854
# batch 18 --- Loss: 0.2688
# batch 19 --- Loss: 0.1770
# batch 20 --- Loss: 0.1705
# batch 21 --- Loss: 0.2036
# batch 22 --- Loss: 0.1560
# batch 23 --- Loss: 0.2372
# batch 24 --- Loss: 0.1728
# batch 25 --- Loss: 0.1579
# batch 26 --- Loss: 0.1782
# batch 27 --- Loss: 0.1566
# batch 28 --- Loss: 0.1613
# batch 29 --- Loss: 0.2608
# batch 30 --- Loss: 0.1869
# batch 31 --- Loss: 0.1606
# batch 32 --- Loss: 0.1576
# batch 33 --- Loss: 0.2973
# batch 34 --- Loss: 0.1723
# batch 35 --- Loss: 0.2607
# batch 36 --- Loss: 0.1877
# batch 37 --- Loss: 0.2520
# batch 38 --- Loss: 0.1427
# batch 39 --- Loss: 0.1950
# batch 40 --- Loss: 0.1329
# batch 41 --- Loss: 0.1330
# batch 42 --- Loss: 0.1220
# batch 43 --- Loss: 0.2091
# batch 44 --- Loss: 0.1851
# Epoch 8 / 20 --- Loss: 0.1967
# Accuracy: 0.7251 ---- Loss: 0.2774
# batch 0 --- Loss: 0.1855
# batch 1 --- Loss: 0.2509
# batch 2 --- Loss: 0.2248
# batch 3 --- Loss: 0.1577
# batch 4 --- Loss: 0.1477
# batch 5 --- Loss: 0.2577
# batch 6 --- Loss: 0.1648
# batch 7 --- Loss: 0.1321
# batch 8 --- Loss: 0.2743
# batch 9 --- Loss: 0.1352
# batch 10 --- Loss: 0.1612
# batch 11 --- Loss: 0.1874
# batch 12 --- Loss: 0.1507
# batch 13 --- Loss: 0.1860
# batch 14 --- Loss: 0.1954
# batch 15 --- Loss: 0.1680
# batch 16 --- Loss: 0.2822
# batch 17 --- Loss: 0.1719
# batch 18 --- Loss: 0.1552
# batch 19 --- Loss: 0.1622
# batch 20 --- Loss: 0.1978
# batch 21 --- Loss: 0.1517
# batch 22 --- Loss: 0.2223
# batch 23 --- Loss: 0.1221
# batch 24 --- Loss: 0.1483
# batch 25 --- Loss: 0.2338
# batch 26 --- Loss: 0.2318
# batch 27 --- Loss: 0.1226
# batch 28 --- Loss: 0.1586
# batch 29 --- Loss: 0.1936
# batch 30 --- Loss: 0.1759
# batch 31 --- Loss: 0.2388
# batch 32 --- Loss: 0.3297
# batch 33 --- Loss: 0.1949
# batch 34 --- Loss: 0.2789
# batch 35 --- Loss: 0.1525
# batch 36 --- Loss: 0.1477
# batch 37 --- Loss: 0.1764
# batch 38 --- Loss: 0.1160
# batch 39 --- Loss: 0.1748
# batch 40 --- Loss: 0.2188
# batch 41 --- Loss: 0.2088
# batch 42 --- Loss: 0.3052
# batch 43 --- Loss: 0.2567
# batch 44 --- Loss: 0.3147
# Epoch 9 / 20 --- Loss: 0.1961
# Accuracy: 0.7536 ---- Loss: 0.2975
# batch 0 --- Loss: 0.1208
# batch 1 --- Loss: 0.2045
# batch 2 --- Loss: 0.2389
# batch 3 --- Loss: 0.3019
# batch 4 --- Loss: 0.2738
# batch 5 --- Loss: 0.1311
# batch 6 --- Loss: 0.2541
# batch 7 --- Loss: 0.2844
# batch 8 --- Loss: 0.1727
# batch 9 --- Loss: 0.1721
# batch 10 --- Loss: 0.1039
# batch 11 --- Loss: 0.2439
# batch 12 --- Loss: 0.2250
# batch 13 --- Loss: 0.1625
# batch 14 --- Loss: 0.2857
# batch 15 --- Loss: 0.1795
# batch 16 --- Loss: 0.1984
# batch 17 --- Loss: 0.1581
# batch 18 --- Loss: 0.3022
# batch 19 --- Loss: 0.2878
# batch 20 --- Loss: 0.1662
# batch 21 --- Loss: 0.3420
# batch 22 --- Loss: 0.3147
# batch 23 --- Loss: 0.1566
# batch 24 --- Loss: 0.1668
# batch 25 --- Loss: 0.1762
# batch 26 --- Loss: 0.1457
# batch 27 --- Loss: 0.2482
# batch 28 --- Loss: 0.1203
# batch 29 --- Loss: 0.3025
# batch 30 --- Loss: 0.1554
# batch 31 --- Loss: 0.1580
# batch 32 --- Loss: 0.1838
# batch 33 --- Loss: 0.1614
# batch 34 --- Loss: 0.1571
# batch 35 --- Loss: 0.2437
# batch 36 --- Loss: 0.1489
# batch 37 --- Loss: 0.2016
# batch 38 --- Loss: 0.1416
# batch 39 --- Loss: 0.1374
# batch 40 --- Loss: 0.1551
# batch 41 --- Loss: 0.1534
# batch 42 --- Loss: 0.1611
# batch 43 --- Loss: 0.1965
# batch 44 --- Loss: 0.1555
# Epoch 10 / 20 --- Loss: 0.1989
# Accuracy: 0.7581 ---- Loss: 0.2633
# batch 0 --- Loss: 0.1112
# batch 1 --- Loss: 0.3664
# batch 2 --- Loss: 0.2139
# batch 3 --- Loss: 0.1534
# batch 4 --- Loss: 0.1216
# batch 5 --- Loss: 0.1783
# batch 6 --- Loss: 0.1425
# batch 7 --- Loss: 0.2095
# batch 8 --- Loss: 0.1577
# batch 9 --- Loss: 0.2089
# batch 10 --- Loss: 0.1237
# batch 11 --- Loss: 0.1352
# batch 12 --- Loss: 0.1578
# batch 13 --- Loss: 0.1798
# batch 14 --- Loss: 0.1684
# batch 15 --- Loss: 0.1417
# batch 16 --- Loss: 0.1367
# batch 17 --- Loss: 0.2873
# batch 18 --- Loss: 0.1542
# batch 19 --- Loss: 0.3965
# batch 20 --- Loss: 0.2101
# batch 21 --- Loss: 0.1228
# batch 22 --- Loss: 0.1397
# batch 23 --- Loss: 0.1751
# batch 24 --- Loss: 0.2268
# batch 25 --- Loss: 0.1623
# batch 26 --- Loss: 0.1493
# batch 27 --- Loss: 0.1621
# batch 28 --- Loss: 0.1657
# batch 29 --- Loss: 0.2246
# batch 30 --- Loss: 0.3010
# batch 31 --- Loss: 0.1160
# batch 32 --- Loss: 0.1604
# batch 33 --- Loss: 0.1918
# batch 34 --- Loss: 0.2330
# batch 35 --- Loss: 0.1415
# batch 36 --- Loss: 0.2957
# batch 37 --- Loss: 0.1591
# batch 38 --- Loss: 0.1782
# batch 39 --- Loss: 0.1299
# batch 40 --- Loss: 0.2572
# batch 41 --- Loss: 0.2861
# batch 42 --- Loss: 0.1277
# batch 43 --- Loss: 0.1621
# batch 44 --- Loss: 0.2853
# Epoch 11 / 20 --- Loss: 0.1891
# Accuracy: 0.7990 ---- Loss: 0.2422
# batch 0 --- Loss: 0.1648
# batch 1 --- Loss: 0.1562
# batch 2 --- Loss: 0.2963
# batch 3 --- Loss: 0.2436
# batch 4 --- Loss: 0.2869
# batch 5 --- Loss: 0.1997
# batch 6 --- Loss: 0.1771
# batch 7 --- Loss: 0.2034
# batch 8 --- Loss: 0.1368
# batch 9 --- Loss: 0.1764
# batch 10 --- Loss: 0.1583
# batch 11 --- Loss: 0.1225
# batch 12 --- Loss: 0.1110
# batch 13 --- Loss: 0.1303
# batch 14 --- Loss: 0.3006
# batch 15 --- Loss: 0.1819
# batch 16 --- Loss: 0.1722
# batch 17 --- Loss: 0.1553
# batch 18 --- Loss: 0.1475
# batch 19 --- Loss: 0.1535
# batch 20 --- Loss: 0.1101
# batch 21 --- Loss: 0.2075
# batch 22 --- Loss: 0.1914
# batch 23 --- Loss: 0.1230
# batch 24 --- Loss: 0.1875
# batch 25 --- Loss: 0.3136
# batch 26 --- Loss: 0.1790
# batch 27 --- Loss: 0.1652
# batch 28 --- Loss: 0.1731
# batch 29 --- Loss: 0.1511
# batch 30 --- Loss: 0.2023
# batch 31 --- Loss: 0.2266
# batch 32 --- Loss: 0.1033
# batch 33 --- Loss: 0.1160
# batch 34 --- Loss: 0.1429
# batch 35 --- Loss: 0.2006
# batch 36 --- Loss: 0.2899
# batch 37 --- Loss: 0.2936
# batch 38 --- Loss: 0.1445
# batch 39 --- Loss: 0.1497
# batch 40 --- Loss: 0.2480
# batch 41 --- Loss: 0.1509
# batch 42 --- Loss: 0.1664
# batch 43 --- Loss: 0.4963
# batch 44 --- Loss: 0.2058
# Epoch 12 / 20 --- Loss: 0.1914
# Accuracy: 0.7746 ---- Loss: 0.3097
# batch 0 --- Loss: 0.2425
# batch 1 --- Loss: 0.1658
# batch 2 --- Loss: 0.2193
# batch 3 --- Loss: 0.2508
# batch 4 --- Loss: 0.1979
# batch 5 --- Loss: 0.1616
# batch 6 --- Loss: 0.2398
# batch 7 --- Loss: 0.2172
# batch 8 --- Loss: 0.2478
# batch 9 --- Loss: 0.1734
# batch 10 --- Loss: 0.1426
# batch 11 --- Loss: 0.1413
# batch 12 --- Loss: 0.1795
# batch 13 --- Loss: 0.1511
# batch 14 --- Loss: 0.1832
# batch 15 --- Loss: 0.3171
# batch 16 --- Loss: 0.1743
# batch 17 --- Loss: 0.1889
# batch 18 --- Loss: 0.1618
# batch 19 --- Loss: 0.3082
# batch 20 --- Loss: 0.1187
# batch 21 --- Loss: 0.1847
# batch 22 --- Loss: 0.2376
# batch 23 --- Loss: 0.2776
# batch 24 --- Loss: 0.1661
# batch 25 --- Loss: 0.1675
# batch 26 --- Loss: 0.1303
# batch 27 --- Loss: 0.1199
# batch 28 --- Loss: 0.2691
# batch 29 --- Loss: 0.1290
# batch 30 --- Loss: 0.2229
# batch 31 --- Loss: 0.1796
# batch 32 --- Loss: 0.1217
# batch 33 --- Loss: 0.2667
# batch 34 --- Loss: 0.1397
# batch 35 --- Loss: 0.1724
# batch 36 --- Loss: 0.1859
# batch 37 --- Loss: 0.2306
# batch 38 --- Loss: 0.1281
# batch 39 --- Loss: 0.1500
# batch 40 --- Loss: 0.1979
# batch 41 --- Loss: 0.3087
# batch 42 --- Loss: 0.1252
# batch 43 --- Loss: 0.2963
# batch 44 --- Loss: 0.1673
# Epoch 13 / 20 --- Loss: 0.1946
# Accuracy: 0.8372 ---- Loss: 0.1942
# batch 0 --- Loss: 0.1511
# batch 1 --- Loss: 0.1556
# batch 2 --- Loss: 0.2034
# batch 3 --- Loss: 0.2926
# batch 4 --- Loss: 0.1324
# batch 5 --- Loss: 0.1521
# batch 6 --- Loss: 0.1417
# batch 7 --- Loss: 0.1380
# batch 8 --- Loss: 0.2982
# batch 9 --- Loss: 0.2041
# batch 10 --- Loss: 0.3754
# batch 11 --- Loss: 0.2837
# batch 12 --- Loss: 0.2949
# batch 13 --- Loss: 0.2193
# batch 14 --- Loss: 0.2614
# batch 15 --- Loss: 0.1228
# batch 16 --- Loss: 0.2139
# batch 17 --- Loss: 0.1633
# batch 18 --- Loss: 0.1981
# batch 19 --- Loss: 0.1527
# batch 20 --- Loss: 0.1765
# batch 21 --- Loss: 0.1451
# batch 22 --- Loss: 0.1732
# batch 23 --- Loss: 0.2195
# batch 24 --- Loss: 0.1975
# batch 25 --- Loss: 0.2439
# batch 26 --- Loss: 0.1502
# batch 27 --- Loss: 0.1937
# batch 28 --- Loss: 0.1801
# batch 29 --- Loss: 0.2200
# batch 30 --- Loss: 0.2072
# batch 31 --- Loss: 0.1541
# batch 32 --- Loss: 0.1677
# batch 33 --- Loss: 0.2686
# batch 34 --- Loss: 0.1341
# batch 35 --- Loss: 0.1305
# batch 36 --- Loss: 0.1646
# batch 37 --- Loss: 0.1273
# batch 38 --- Loss: 0.1455
# batch 39 --- Loss: 0.1392
# batch 40 --- Loss: 0.1671
# batch 41 --- Loss: 0.1759
# batch 42 --- Loss: 0.3057
# batch 43 --- Loss: 0.1284
# batch 44 --- Loss: 0.1702
# Epoch 14 / 20 --- Loss: 0.1920
# Accuracy: 0.7908 ---- Loss: 0.2521
# batch 0 --- Loss: 0.1202
# batch 1 --- Loss: 0.1736
# batch 2 --- Loss: 0.2339
# batch 3 --- Loss: 0.1291
# batch 4 --- Loss: 0.3725
# batch 5 --- Loss: 0.2728
# batch 6 --- Loss: 0.1807
# batch 7 --- Loss: 0.2175
# batch 8 --- Loss: 0.1881
# batch 9 --- Loss: 0.1210
# batch 10 --- Loss: 0.1233
# batch 11 --- Loss: 0.1793
# batch 12 --- Loss: 0.2098
# batch 13 --- Loss: 0.1490
# batch 14 --- Loss: 0.2706
# batch 15 --- Loss: 0.2310
# batch 16 --- Loss: 0.1446
# batch 17 --- Loss: 0.1891
# batch 18 --- Loss: 0.1499
# batch 19 --- Loss: 0.1395
# batch 20 --- Loss: 0.1868
# batch 21 --- Loss: 0.1967
# batch 22 --- Loss: 0.1580
# batch 23 --- Loss: 0.1520
# batch 24 --- Loss: 0.2061
# batch 25 --- Loss: 0.2855
# batch 26 --- Loss: 0.2134
# batch 27 --- Loss: 0.1741
# batch 28 --- Loss: 0.1035
# batch 29 --- Loss: 0.1110
# batch 30 --- Loss: 0.2961
# batch 31 --- Loss: 0.1437
# batch 32 --- Loss: 0.1377
# batch 33 --- Loss: 0.1627
# batch 34 --- Loss: 0.1518
# batch 35 --- Loss: 0.3403
# batch 36 --- Loss: 0.2763
# batch 37 --- Loss: 0.1808
# batch 38 --- Loss: 0.2834
# batch 39 --- Loss: 0.1306
# batch 40 --- Loss: 0.2056
# batch 41 --- Loss: 0.2423
# batch 42 --- Loss: 0.1367
# batch 43 --- Loss: 0.1578
# batch 44 --- Loss: 0.1404
# Epoch 15 / 20 --- Loss: 0.1904
# Accuracy: 0.8131 ---- Loss: 0.2290
# batch 0 --- Loss: 0.1703
# batch 1 --- Loss: 0.1889
# batch 2 --- Loss: 0.1222
# batch 3 --- Loss: 0.1085
# batch 4 --- Loss: 0.1541
# batch 5 --- Loss: 0.1463
# batch 6 --- Loss: 0.1696
# batch 7 --- Loss: 0.2116
# batch 8 --- Loss: 0.1863
# batch 9 --- Loss: 0.2774
# batch 10 --- Loss: 0.1648
# batch 11 --- Loss: 0.1871
# batch 12 --- Loss: 0.1140
# batch 13 --- Loss: 0.1654
# batch 14 --- Loss: 0.2846
# batch 15 --- Loss: 0.1817
# batch 16 --- Loss: 0.1413
# batch 17 --- Loss: 0.1620
# batch 18 --- Loss: 0.2179
# batch 19 --- Loss: 0.1018
# batch 20 --- Loss: 0.1732
# batch 21 --- Loss: 0.3042
# batch 22 --- Loss: 0.1874
# batch 23 --- Loss: 0.3158
# batch 24 --- Loss: 0.1472
# batch 25 --- Loss: 0.1464
# batch 26 --- Loss: 0.1664
# batch 27 --- Loss: 0.1773
# batch 28 --- Loss: 0.1422
# batch 29 --- Loss: 0.1414
# batch 30 --- Loss: 0.1425
# batch 31 --- Loss: 0.2362
# batch 32 --- Loss: 0.3342
# batch 33 --- Loss: 0.3148
# batch 34 --- Loss: 0.2018
# batch 35 --- Loss: 0.2836
# batch 36 --- Loss: 0.2781
# batch 37 --- Loss: 0.1001
# batch 38 --- Loss: 0.1789
# batch 39 --- Loss: 0.1091
# batch 40 --- Loss: 0.1632
# batch 41 --- Loss: 0.2191
# batch 42 --- Loss: 0.1062
# batch 43 --- Loss: 0.1614
# batch 44 --- Loss: 0.2466
# Epoch 16 / 20 --- Loss: 0.1874
# Accuracy: 0.7532 ---- Loss: 0.2559
# batch 0 --- Loss: 0.2531
# batch 1 --- Loss: 0.1438
# batch 2 --- Loss: 0.1859
# batch 3 --- Loss: 0.2403
# batch 4 --- Loss: 0.1634
# batch 5 --- Loss: 0.1940
# batch 6 --- Loss: 0.2105
# batch 7 --- Loss: 0.2243
# batch 8 --- Loss: 0.1737
# batch 9 --- Loss: 0.3374
# batch 10 --- Loss: 0.1838
# batch 11 --- Loss: 0.1873
# batch 12 --- Loss: 0.2219
# batch 13 --- Loss: 0.1259
# batch 14 --- Loss: 0.1985
# batch 15 --- Loss: 0.1823
# batch 16 --- Loss: 0.1842
# batch 17 --- Loss: 0.1276
# batch 18 --- Loss: 0.1712
# batch 19 --- Loss: 0.1790
# batch 20 --- Loss: 0.2713
# batch 21 --- Loss: 0.2917
# batch 22 --- Loss: 0.1205
# batch 23 --- Loss: 0.1539
# batch 24 --- Loss: 0.3764
# batch 25 --- Loss: 0.2284
# batch 26 --- Loss: 0.1527
# batch 27 --- Loss: 0.1928
# batch 28 --- Loss: 0.1540
# batch 29 --- Loss: 0.1345
# batch 30 --- Loss: 0.1522
# batch 31 --- Loss: 0.2581
# batch 32 --- Loss: 0.1546
# batch 33 --- Loss: 0.1485
# batch 34 --- Loss: 0.1815
# batch 35 --- Loss: 0.2458
# batch 36 --- Loss: 0.1511
# batch 37 --- Loss: 0.1398
# batch 38 --- Loss: 0.2331
# batch 39 --- Loss: 0.2522
# batch 40 --- Loss: 0.1951
# batch 41 --- Loss: 0.1861
# batch 42 --- Loss: 0.1386
# batch 43 --- Loss: 0.1334
# batch 44 --- Loss: 0.2115
# Epoch 17 / 20 --- Loss: 0.1944
# Accuracy: 0.8219 ---- Loss: 0.2097
# batch 0 --- Loss: 0.1477
# batch 1 --- Loss: 0.1564
# batch 2 --- Loss: 0.2425
# batch 3 --- Loss: 0.2318
# batch 4 --- Loss: 0.1960
# batch 5 --- Loss: 0.1509
# batch 6 --- Loss: 0.1725
# batch 7 --- Loss: 0.1721
# batch 8 --- Loss: 0.1906
# batch 9 --- Loss: 0.1613
# batch 10 --- Loss: 0.4051
# batch 11 --- Loss: 0.1667
# batch 12 --- Loss: 0.1869
# batch 13 --- Loss: 0.2558
# batch 14 --- Loss: 0.1592
# batch 15 --- Loss: 0.1465
# batch 16 --- Loss: 0.1848
# batch 17 --- Loss: 0.2430
# batch 18 --- Loss: 0.2045
# batch 19 --- Loss: 0.1789
# batch 20 --- Loss: 0.1431
# batch 21 --- Loss: 0.1418
# batch 22 --- Loss: 0.1600
# batch 23 --- Loss: 0.1618
# batch 24 --- Loss: 0.1818
# batch 25 --- Loss: 0.1798
# batch 26 --- Loss: 0.2522
# batch 27 --- Loss: 0.2647
# batch 28 --- Loss: 0.1097
# batch 29 --- Loss: 0.1212
# batch 30 --- Loss: 0.2350
# batch 31 --- Loss: 0.1623
# batch 32 --- Loss: 0.1606
# batch 33 --- Loss: 0.1221
# batch 34 --- Loss: 0.1815
# batch 35 --- Loss: 0.1646
# batch 36 --- Loss: 0.2107
# batch 37 --- Loss: 0.1557
# batch 38 --- Loss: 0.1494
# batch 39 --- Loss: 0.1430
# batch 40 --- Loss: 0.1581
# batch 41 --- Loss: 0.1554
# batch 42 --- Loss: 0.1540
# batch 43 --- Loss: 0.1566
# batch 44 --- Loss: 0.2334
# Epoch 18 / 20 --- Loss: 0.1825
# Accuracy: 0.7638 ---- Loss: 0.3054
# batch 0 --- Loss: 0.1987
# batch 1 --- Loss: 0.2066
# batch 2 --- Loss: 0.1337
# batch 3 --- Loss: 0.2609
# batch 4 --- Loss: 0.1428
# batch 5 --- Loss: 0.2838
# batch 6 --- Loss: 0.3077
# batch 7 --- Loss: 0.2538
# batch 8 --- Loss: 0.1538
# batch 9 --- Loss: 0.2826
# batch 10 --- Loss: 0.1541
# batch 11 --- Loss: 0.2862
# batch 12 --- Loss: 0.1545
# batch 13 --- Loss: 0.1612
# batch 14 --- Loss: 0.1625
# batch 15 --- Loss: 0.1424
# batch 16 --- Loss: 0.1511
# batch 17 --- Loss: 0.2202
# batch 18 --- Loss: 0.2728
# batch 19 --- Loss: 0.1871
# batch 20 --- Loss: 0.1066
# batch 21 --- Loss: 0.1695
# batch 22 --- Loss: 0.3815
# batch 23 --- Loss: 0.2679
# batch 24 --- Loss: 0.1350
# batch 25 --- Loss: 0.1762
# batch 26 --- Loss: 0.1373
# batch 27 --- Loss: 0.3771
# batch 28 --- Loss: 0.2043
# batch 29 --- Loss: 0.3340
# batch 30 --- Loss: 0.1972
# batch 31 --- Loss: 0.1469
# batch 32 --- Loss: 0.1796
# batch 33 --- Loss: 0.2987
# batch 34 --- Loss: 0.1328
# batch 35 --- Loss: 0.1594
# batch 36 --- Loss: 0.1820
# batch 37 --- Loss: 0.1744
# batch 38 --- Loss: 0.1460
# batch 39 --- Loss: 0.3002
# batch 40 --- Loss: 0.2824
# batch 41 --- Loss: 0.2951
# batch 42 --- Loss: 0.1646
# batch 43 --- Loss: 0.1814
# batch 44 --- Loss: 0.1380
# Epoch 19 / 20 --- Loss: 0.2085
# Accuracy: 0.8258 ---- Loss: 0.2015
# batch 0 --- Loss: 0.1404
# batch 1 --- Loss: 0.1662
# batch 2 --- Loss: 0.2014
# batch 3 --- Loss: 0.1782
# batch 4 --- Loss: 0.1504
# batch 5 --- Loss: 0.2871
# batch 6 --- Loss: 0.1721
# batch 7 --- Loss: 0.1236
# batch 8 --- Loss: 0.1614
# batch 9 --- Loss: 0.1380
# batch 10 --- Loss: 0.3062
# batch 11 --- Loss: 0.1642
# batch 12 --- Loss: 0.2760
# batch 13 --- Loss: 0.1342
# batch 14 --- Loss: 0.1746
# batch 15 --- Loss: 0.2728
# batch 16 --- Loss: 0.2263
# batch 17 --- Loss: 0.2268
# batch 18 --- Loss: 0.1871
# batch 19 --- Loss: 0.1725
# batch 20 --- Loss: 0.1421
# batch 21 --- Loss: 0.3083
# batch 22 --- Loss: 0.1555
# batch 23 --- Loss: 0.2090
# batch 24 --- Loss: 0.1876
# batch 25 --- Loss: 0.1494
# batch 26 --- Loss: 0.2384
# batch 27 --- Loss: 0.1732
# batch 28 --- Loss: 0.2780
# batch 29 --- Loss: 0.2240
# batch 30 --- Loss: 0.1642
# batch 31 --- Loss: 0.1645
# batch 32 --- Loss: 0.1784
# batch 33 --- Loss: 0.1980
# batch 34 --- Loss: 0.2039
# batch 35 --- Loss: 0.2454
# batch 36 --- Loss: 0.1627
# batch 37 --- Loss: 0.1812
# batch 38 --- Loss: 0.2626
# batch 39 --- Loss: 0.1723
# batch 40 --- Loss: 0.1513
# batch 41 --- Loss: 0.1303
# batch 42 --- Loss: 0.1640
# batch 43 --- Loss: 0.1587
# batch 44 --- Loss: 0.2399
# Epoch 20 / 20 --- Loss: 0.1934
# Accuracy: 0.8284 ---- Loss: 0.1995

# %% [markdown]
# ### Testing and Visualization

# %%
model.eval()

output_masks = []
output_labels = []

def Threshold(label, output):
    pass

with torch.no_grad():
    for i in range(testset.__len__()):
        image, labels = testset.__getitem__(i)
    
        input_image = image.unsqueeze(0).to(device)
        pred = model(input_image)

        output_mask = torch.max(pred, dim = 1)[1].cpu().squeeze(0).numpy()#.astype(np.float32)

        labels = labels[0]
        crop_x = (labels.shape[0] - output_mask.shape[0]) // 2
        crop_y = (labels.shape[1] - output_mask.shape[1]) // 2
        labels = labels[crop_x: labels.shape[0] - crop_x, crop_y: labels.shape[1] - crop_y].numpy()
    
        output_masks.append(output_mask)
        output_labels.append(labels)

# %%
fig, axes = plt.subplots(testset.__len__(), 2, figsize = (10, 70))

for i in range(testset.__len__()):
    axes[i, 0].imshow(output_labels[i],cmap='gray')
    axes[i, 0].axis('off')
    axes[i, 1].imshow(output_masks[i],cmap='gray')
    axes[i, 1].axis('off')
