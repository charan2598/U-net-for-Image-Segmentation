# %% [markdown]
# ### Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

import torch.optim as optim

import os

from PIL import Image, ImageOps

import random

#import any other library you need below this line
import math

# %% [markdown]
# ### Loading data
#
# Upload the data in zip format to Colab. Then run the cell below.

# %%
#!unzip data.zip

# %% [markdown]
# ### Defining the Dataset Class

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
class Cell_data(Dataset):
    def __init__(self, data_dir, size, train = True, train_test_split = 0.8, augment_data = True, transform = None):
        ##########################inputs##################################
        #data_dir(string) - directory of the data#########################
        #size(int) - size of the images you want to use###################
        #train(boolean) - train data or test data#########################
        #train_test_split(float) - the portion of the data for training###
        #augment_data(boolean) - use data augmentation or not#############
        super(Cell_data, self).__init__()
        # todo
        #initialize the data class
        self.image_files = os.listdir(data_dir+"/scans")
        self.transform = transform
        train_test_split = math.floor(train_test_split*len(self.image_files))

        self.augmented_images_dir = data_dir+"/augmented_data"
        if not os.path.exists(self.augmented_images_dir):
            os.mkdir(self.augmented_images_dir)

        random.shuffle(self.image_files)
        if train == True:
            train_image_files = self.augmented_images_dir+"/train"
            os.mkdir(train_image_files)
            os.mkdir(train_image_files+"/scans")
            os.mkdir(train_image_files+"/labels")
            self.final_images_dir = train_image_files
            dataset_for_augmentation = self.image_files[:train_test_split]
        else:
            test_image_files = self.augmented_images_dir+"/test"
            os.mkdir(test_image_files)
            os.mkdir(test_image_files+"/scans")
            os.mkdir(test_image_files+"/labels")
            self.final_images_dir = test_image_files
            dataset_for_augmentation = self.image_files[train_test_split:]

        image_count=1
        for image in dataset_for_augmentation:
            scan_image = Image.open(data_dir+"/scans/"+image)
            scan_image = scan_image.resize((size, size))
            label_image = Image.open(data_dir+"/labels/"+image)
            label_image = label_image.resize((size, size))
            #data augmentation part
            if augment_data:
                augment_mode = np.random.randint(0, 4) ############## Ignoring the case of zoom and gamma correction so reduced range from 5 to 4
                if augment_mode == 0 or augment_mode == 1:
                    #todo 
                    #flip image vertically
                    augmented_scan_image_1 = TF.vflip(scan_image)
                    augmented_label_image_1 = TF.vflip(label_image)

                    #todo
                    #flip image horizontally
                    augmented_scan_image_2 = TF.hflip(scan_image)
                    augmented_label_image_2 = TF.hflip(label_image)
                elif augment_mode == 2 or augment_mode == 3:
                    #todo
                    #rotate image
                    angle = random.randint(-30, 30)
                    augmented_scan_image_1 = TF.rotate(scan_image, angle)
                    augmented_label_image_1 = TF.rotate(label_image, angle)

                    #Gamma correction
                    gamma = random.randrange(3,8)/10
                    augmented_scan_image_2 = TF.adjust_gamma(scan_image, gamma)
                    augmented_label_image_2 = label_image
                else: # Not used for now
                    #todo
                    #zoom image
                    zoom_size = random.randint(int(self.size*0.75), self.size)
                    augmented_scan_image_1 = TF.center_crop(scan_image, zoom_size)
                    augmented_label_image_1 = TF.center_crop(label_image, zoom_size)
                
                #write the files to the augmented data location
                scan_image.save(self.final_images_dir+"/scans/"+str(image_count)+".bmp") # original image is saved as 1.bmp
                augmented_scan_image_1.save(self.final_images_dir+"/scans/"+str(image_count+1)+".bmp") # augmented image is saved as 2.jpg
                augmented_scan_image_2.save(self.final_images_dir+"/scans/"+str(image_count+2)+".bmp") # augmented image is saved as 3.jpg
                label_image.save(self.final_images_dir+"/labels/"+str(image_count)+".bmp") # original label is saved as 1.bmp
                augmented_label_image_1.save(self.final_images_dir+"/labels/"+str(image_count+1)+".bmp") # augmented label is saved as 2.jpg
                augmented_label_image_2.save(self.final_images_dir+"/labels/"+str(image_count+2)+".bmp") # augmented label is saved as 3.jpg
                image_count+=3
        
        self.dataset = os.listdir(self.final_images_dir+"/scans")


    def __getitem__(self, idx):
        # todo
        #load image and mask from index idx of your data
        filename = self.dataset[idx]
        scan_image = Image.open(self.final_images_dir+"/scans/"+filename)
        label_image = Image.open(self.final_images_dir+"/labels/"+filename)
        #todo
        #return image and mask in tensors

        return self.transform(scan_image), torch.ceil(self.transform(label_image))

    def __len__(self):
        return len(self.dataset)

# %% [markdown]
# ### Define the Model
# 1. Define the Convolution blocks
# 2. Define the down path
# 3. Define the up path
# 4. combine the down and up path to get the final model

# %%
TEMP = False
class twoConvBlock(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(twoConvBlock, self).__init__()
        #todo
        #initialize the block
        self.conv_layer1 = nn.Conv2d(input_channels, output_channels, kernel_size=3, stride=1)
        self.conv_layer2 = nn.Conv2d(output_channels, output_channels, kernel_size=3, stride=1)
        self.batch_norm_layer = nn.BatchNorm2d(output_channels)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.conv_layer1(image)
        image = F.relu(image)
        image = self.conv_layer2(image)
        image = self.batch_norm_layer(image)
        image = F.relu(image)
        return image

class downStep(nn.Module):
    def __init__(self):
        super(downStep, self).__init__()
        #todo
        #initialize the down path
        self.max_pool_layer = nn.MaxPool2d(kernel_size=2,stride=2)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.max_pool_layer(image)
        return image

class upStep(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(upStep, self).__init__()
        #todo
        #initialize the up path
        self.up_sampling_layer = nn.ConvTranspose2d(input_channels, output_channels, kernel_size=2, stride=2)

    def forward(self, image):
        #todo
        #implement the forward path
        image = self.up_sampling_layer(image)
        return image

def crop_tensor(input_copy, ideal_size):
    h_delta = (input_copy.shape[2]-ideal_size.shape[2]) // 2
    w_delta = (input_copy.shape[3]-ideal_size.shape[3]) // 2
    return input_copy[:,:,h_delta:input_copy.shape[2]-h_delta, w_delta:input_copy.shape[3]-w_delta]

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        #todo
        #initialize the complete model
        self.conv1 = twoConvBlock(1, 64)
        self.conv2 = twoConvBlock(64, 128)
        self.conv3 = twoConvBlock(128, 256)
        self.conv4 = twoConvBlock(256, 512)
        self.conv5 = twoConvBlock(512, 1024)
        self.conv6 = twoConvBlock(1024, 512)
        self.conv7 = twoConvBlock(512, 256)
        self.conv8 = twoConvBlock(256, 128)
        self.conv9 = twoConvBlock(128, 64)
        self.conv10 = nn.Conv2d(in_channels=64, out_channels=2, kernel_size=1, stride=1)
        self.down_step = downStep()
        self.up_step1 = upStep(1024, 512)
        self.up_step2 = upStep(512, 256)
        self.up_step3 = upStep(256,128)
        self.up_step4 = upStep(128,64)

    def forward(self, input):
        #todo
        #implement the forward path
        conv1_op = self.conv1(input)
        down_sampled = self.down_step(conv1_op)
        conv2_op = self.conv2(down_sampled)
        down_sampled = self.down_step(conv2_op)
        conv3_op = self.conv3(down_sampled)
        down_sampled = self.down_step(conv3_op)
        conv4_op = self.conv4(down_sampled)
        down_sampled = self.down_step(conv4_op)
        conv5_op = self.conv5(down_sampled)
        up_sampled = self.up_step1(conv5_op)
        # Conv 6 output is the one below
        conv_op = self.conv6(torch.cat(tensors=(up_sampled, crop_tensor(conv4_op, up_sampled)), dim=1))
        up_sampled = self.up_step2(conv_op)
        conv_op = self.conv7(torch.cat(tensors=(up_sampled, crop_tensor(conv3_op, up_sampled)), dim=1))
        up_sampled = self.up_step3(conv_op)
        conv_op = self.conv8(torch.cat(tensors=(up_sampled, crop_tensor(conv2_op, up_sampled)), dim=1))
        up_sampled = self.up_step4(conv_op)
        conv_op = self.conv9(torch.cat(tensors=(up_sampled, crop_tensor(conv1_op, up_sampled)), dim=1))
        conv_op = self.conv10(conv_op)

        return conv_op

# %% [markdown]
# ### Training

# %%
import wandb

wandb.init(project="U-Net_Model")

wandb.config = {
  "learning_rate": 0.001,
  "epochs": 20,
  "batch_size": 2
}
# Out:
# Finishing last run (ID:a8wy5pfb) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test loss</td><td>█▄▁▂▂▃▁▅▂▁▃▂▁▁▄▃▄▂▂▁</td></tr><tr><td>Train loss</td><td>▆▄▅▁▆▂▇▂▃███▆▃▁▄█▄▄▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test loss</td><td>0.25886</td></tr><tr><td>Train loss</td><td>0.26052</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sunset-2</strong>: <a href="https://wandb.ai/charan250498/U-Net_Model/runs/a8wy5pfb" target="_blank">https://wandb.ai/charan250498/U-Net_Model/runs/a8wy5pfb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221031_220124-a8wy5pfb\logs</code>
# Successfully finished last run (ID:a8wy5pfb). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>c:\Users\chara\OneDrive\Desktop\CMPT732 G200 Lab\Assignments\Assignment 2\A2\wandb\run-20221031_222214-2i030574</code>
# Syncing run <strong><a href="https://wandb.ai/charan250498/U-Net_Model/runs/2i030574" target="_blank">earnest-feather-3</a></strong> to <a href="https://wandb.ai/charan250498/U-Net_Model" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
#Paramteres

#learning rate
lr = 1e-2

#number of training epochs
epoch_n = 100

#input image-mask size
image_size = 572
#root directory of project
root_dir = os.getcwd()

#training batch size
batch_size = 2

#use checkpoint model for training
load = False

#use GPU for training
gpu = True

data_dir = os.path.join(root_dir, 'data/cells')

trainset = Cell_data(data_dir = data_dir, size = image_size, transform = transform)
trainloader = DataLoader(trainset, batch_size = batch_size, shuffle=True)

testset = Cell_data(data_dir = data_dir, size = image_size, train = False, transform = transform)
testloader = DataLoader(testset, batch_size = batch_size)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = UNet().to(device)

if load:
    print('loading model')
    model.load_state_dict(torch.load('checkpoint.pt'))

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.0005)
#optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.99, weight_decay=0.0005)

# %%
model.train()
for e in range(epoch_n):
    epoch_loss = 0
    model.train()
    for i, data in enumerate(trainloader):
        image, label = data

        image = image.to(device)
        label = label.long().to(device)

        pred = model(image)

        crop_x = (label.shape[2] - pred.shape[2]) // 2
        crop_y = (label.shape[3] - pred.shape[3]) // 2

        label = label[:, :, crop_x: label.shape[2] - crop_x, crop_y: label.shape[3] - crop_y]

        pred = torch.squeeze(pred,1)
        label = torch.squeeze(label,1)
    
        loss = criterion(pred, label)

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()

        epoch_loss += loss.item()

        print('batch %d --- Loss: %.4f' % (i, loss.item() / batch_size)) ############################# Uncomment this later
    print('Epoch %d / %d --- Loss: %.4f' % (e + 1, epoch_n, epoch_loss / trainset.__len__()))

    wandb.log({"Train loss": epoch_loss / trainset.__len__()})

    torch.save(model.state_dict(), 'checkpoint.pt') # Commented this out for now ##############################

    model.eval()

    total = 0
    correct = 0
    total_loss = 0

    with torch.no_grad():
        for i, data in enumerate(testloader):
            image, label = data

            #image = image.unsqueeze(1).to(device)
            image = image.to(device)
            label = label.long().to(device)

            pred = model(image)
            crop_x = (label.shape[2] - pred.shape[2]) // 2
            crop_y = (label.shape[3] - pred.shape[3]) // 2

            label = label[:, :, crop_x: label.shape[2] - crop_x, crop_y: label.shape[3] - crop_y]
            
            pred = torch.squeeze(pred,1)
            label = torch.squeeze(label,1)

            loss = criterion(pred, label)
            total_loss += loss.item()

            _, pred_labels = torch.max(pred, dim = 1)

            total += label.shape[0] * label.shape[1] * label.shape[2]
            correct += (pred_labels == label).sum().item()

        print('Accuracy: %.4f ---- Loss: %.4f' % (correct / total, total_loss / testset.__len__()))

        wandb.log({"Accuracy": correct * 100 / total})
        wandb.log({"Test loss": total_loss / testset.__len__()})

wandb.watch(model)
# Out:
# batch 0 --- Loss: 0.3759
# batch 1 --- Loss: 0.4010
# batch 2 --- Loss: 0.3754
# batch 3 --- Loss: 0.2054
# batch 4 --- Loss: 0.3336
# batch 5 --- Loss: 0.2112
# batch 6 --- Loss: 0.2575
# batch 7 --- Loss: 0.2371
# batch 8 --- Loss: 0.2079
# batch 9 --- Loss: 0.2614
# batch 10 --- Loss: 0.2838
# batch 11 --- Loss: 0.1844
# batch 12 --- Loss: 0.2592
# batch 13 --- Loss: 0.5145
# batch 14 --- Loss: 0.2384
# batch 15 --- Loss: 0.2444
# batch 16 --- Loss: 0.2423
# batch 17 --- Loss: 0.3700
# batch 18 --- Loss: 0.1649
# batch 19 --- Loss: 0.2689
# batch 20 --- Loss: 0.1877
# batch 21 --- Loss: 0.2643
# batch 22 --- Loss: 0.1703
# batch 23 --- Loss: 0.1983
# batch 24 --- Loss: 0.1553
# batch 25 --- Loss: 0.3241
# batch 26 --- Loss: 0.1598
# batch 27 --- Loss: 0.4196
# batch 28 --- Loss: 0.1645
# batch 29 --- Loss: 0.1878
# batch 30 --- Loss: 0.4776
# batch 31 --- Loss: 0.4216
# batch 32 --- Loss: 0.1823
# batch 33 --- Loss: 0.2540
# batch 34 --- Loss: 0.3010
# batch 35 --- Loss: 0.3822
# batch 36 --- Loss: 0.2695
# batch 37 --- Loss: 0.2430
# batch 38 --- Loss: 0.2820
# batch 39 --- Loss: 0.1850
# batch 40 --- Loss: 0.2008
# batch 41 --- Loss: 0.1811
# batch 42 --- Loss: 0.1833
# batch 43 --- Loss: 0.3088
# batch 44 --- Loss: 0.3456
# Epoch 1 / 100 --- Loss: 0.2686
# Accuracy: 0.8269 ---- Loss: 0.2062
# batch 0 --- Loss: 0.2832
# batch 1 --- Loss: 0.2781
# batch 2 --- Loss: 0.3080
# batch 3 --- Loss: 0.2145
# batch 4 --- Loss: 0.1911
# batch 5 --- Loss: 0.3203
# batch 6 --- Loss: 0.1737
# batch 7 --- Loss: 0.2472
# batch 8 --- Loss: 0.2047
# batch 9 --- Loss: 0.2095
# batch 10 --- Loss: 0.1615
# batch 11 --- Loss: 0.2517
# batch 12 --- Loss: 0.2491
# batch 13 --- Loss: 0.1663
# batch 14 --- Loss: 0.4380
# batch 15 --- Loss: 0.3432
# batch 16 --- Loss: 0.2453
# batch 17 --- Loss: 0.3913
# batch 18 --- Loss: 0.2072
# batch 19 --- Loss: 0.2436
# batch 20 --- Loss: 0.1788
# batch 21 --- Loss: 0.1660
# batch 22 --- Loss: 0.1752
# batch 23 --- Loss: 0.1985
# batch 24 --- Loss: 0.2352
# batch 25 --- Loss: 0.2065
# batch 26 --- Loss: 0.2760
# batch 27 --- Loss: 0.3575
# batch 28 --- Loss: 0.2303
# batch 29 --- Loss: 0.2375
# batch 30 --- Loss: 0.1987
# batch 31 --- Loss: 0.2039
# batch 32 --- Loss: 0.2514
# batch 33 --- Loss: 0.2381
# batch 34 --- Loss: 0.2834
# batch 35 --- Loss: 0.3618
# batch 36 --- Loss: 0.3315
# batch 37 --- Loss: 0.3003
# batch 38 --- Loss: 0.2436
# batch 39 --- Loss: 0.2303
# batch 40 --- Loss: 0.2972
# batch 41 --- Loss: 0.2384
# batch 42 --- Loss: 0.2526
# batch 43 --- Loss: 0.3281
# batch 44 --- Loss: 0.2428
# Epoch 2 / 100 --- Loss: 0.2531
# Accuracy: 0.8228 ---- Loss: 0.2345
# batch 0 --- Loss: 0.2017
# batch 1 --- Loss: 0.2066
# batch 2 --- Loss: 0.1965
# batch 3 --- Loss: 0.1938
# batch 4 --- Loss: 0.4987
# batch 5 --- Loss: 0.1951
# batch 6 --- Loss: 0.2194
# batch 7 --- Loss: 0.4257
# batch 8 --- Loss: 0.2362
# batch 9 --- Loss: 0.3097
# batch 10 --- Loss: 0.2571
# batch 11 --- Loss: 0.2947
# batch 12 --- Loss: 0.2656
# batch 13 --- Loss: 0.2400
# batch 14 --- Loss: 0.2457
# batch 15 --- Loss: 0.1960
# batch 16 --- Loss: 0.1932
# batch 17 --- Loss: 0.1680
# batch 18 --- Loss: 0.2031
# batch 19 --- Loss: 0.2101
# batch 20 --- Loss: 0.3244
# batch 21 --- Loss: 0.4585
# batch 22 --- Loss: 0.2497
# batch 23 --- Loss: 0.1802
# batch 24 --- Loss: 0.2726
# batch 25 --- Loss: 0.2402
# batch 26 --- Loss: 0.1737
# batch 27 --- Loss: 0.2928
# batch 28 --- Loss: 0.2048
# batch 29 --- Loss: 0.2174
# batch 30 --- Loss: 0.1967
# batch 31 --- Loss: 0.1911
# batch 32 --- Loss: 0.1818
# batch 33 --- Loss: 0.2935
# batch 34 --- Loss: 0.2210
# batch 35 --- Loss: 0.2292
# batch 36 --- Loss: 0.2879
# batch 37 --- Loss: 0.2377
# batch 38 --- Loss: 0.5659
# batch 39 --- Loss: 0.4131
# batch 40 --- Loss: 0.3646
# batch 41 --- Loss: 0.1911
# batch 42 --- Loss: 0.2956
# batch 43 --- Loss: 0.2889
# batch 44 --- Loss: 0.2097
# Epoch 3 / 100 --- Loss: 0.2609
# Accuracy: 0.7199 ---- Loss: 0.2465
# batch 0 --- Loss: 0.2453
# batch 1 --- Loss: 0.2407
# batch 2 --- Loss: 0.2833
# batch 3 --- Loss: 0.2230
# batch 4 --- Loss: 0.2041
# batch 5 --- Loss: 0.2231
# batch 6 --- Loss: 0.2229
# batch 7 --- Loss: 0.3763
# batch 8 --- Loss: 0.2595
# batch 9 --- Loss: 0.2442
# batch 10 --- Loss: 0.2188
# batch 11 --- Loss: 0.1978
# batch 12 --- Loss: 0.1451
# batch 13 --- Loss: 0.2348
# batch 14 --- Loss: 0.2430
# batch 15 --- Loss: 0.2665
# batch 16 --- Loss: 0.4076
# batch 17 --- Loss: 0.2637
# batch 18 --- Loss: 0.2207
# batch 19 --- Loss: 0.1708
# batch 20 --- Loss: 0.1899
# batch 21 --- Loss: 0.3439
# batch 22 --- Loss: 0.3625
# batch 23 --- Loss: 0.2616
# batch 24 --- Loss: 0.1691
# batch 25 --- Loss: 0.3156
# batch 26 --- Loss: 0.2213
# batch 27 --- Loss: 0.1912
# batch 28 --- Loss: 0.2432
# batch 29 --- Loss: 0.3309
# batch 30 --- Loss: 0.3293
# batch 31 --- Loss: 0.1880
# batch 32 --- Loss: 0.2916
# batch 33 --- Loss: 0.1928
# batch 34 --- Loss: 0.2655
# batch 35 --- Loss: 0.2106
# batch 36 --- Loss: 0.1875
# batch 37 --- Loss: 0.2506
# batch 38 --- Loss: 0.2769
# batch 39 --- Loss: 0.2046
# batch 40 --- Loss: 0.2837
# batch 41 --- Loss: 0.1886
# batch 42 --- Loss: 0.1902
# batch 43 --- Loss: 0.3006
# batch 44 --- Loss: 0.2631
# Epoch 4 / 100 --- Loss: 0.2476
# Accuracy: 0.7088 ---- Loss: 0.2493
# batch 0 --- Loss: 0.2881
# batch 1 --- Loss: 0.3705
# batch 2 --- Loss: 0.1940
# batch 3 --- Loss: 0.2232
# batch 4 --- Loss: 0.1892
# batch 5 --- Loss: 0.1434
# batch 6 --- Loss: 0.3190
# batch 7 --- Loss: 0.2358
# batch 8 --- Loss: 0.1957
# batch 9 --- Loss: 0.2525
# batch 10 --- Loss: 0.2471
# batch 11 --- Loss: 0.3472
# batch 12 --- Loss: 0.2687
# batch 13 --- Loss: 0.2955
# batch 14 --- Loss: 0.2849
# batch 15 --- Loss: 0.2173
# batch 16 --- Loss: 0.3039
# batch 17 --- Loss: 0.1404
# batch 18 --- Loss: 0.3660
# batch 19 --- Loss: 0.2454
# batch 20 --- Loss: 0.3214
# batch 21 --- Loss: 0.1743
# batch 22 --- Loss: 0.2626
# batch 23 --- Loss: 0.2159
# batch 24 --- Loss: 0.3060
# batch 25 --- Loss: 0.2815
# batch 26 --- Loss: 0.2080
# batch 27 --- Loss: 0.2350
# batch 28 --- Loss: 0.1914
# batch 29 --- Loss: 0.2846
# batch 30 --- Loss: 0.3228
# batch 31 --- Loss: 0.2212
# batch 32 --- Loss: 0.1920
# batch 33 --- Loss: 0.2090
# batch 34 --- Loss: 0.3821
# batch 35 --- Loss: 0.1825
# batch 36 --- Loss: 0.2826
# batch 37 --- Loss: 0.3167
# batch 38 --- Loss: 0.3028
# batch 39 --- Loss: 0.1983
# batch 40 --- Loss: 0.2145
# batch 41 --- Loss: 0.1810
# batch 42 --- Loss: 0.2122
# batch 43 --- Loss: 0.2130
# batch 44 --- Loss: 0.3154
# Epoch 5 / 100 --- Loss: 0.2523
# Accuracy: 0.6893 ---- Loss: 0.2643
# batch 0 --- Loss: 0.3607
# batch 1 --- Loss: 0.1764
# batch 2 --- Loss: 0.1499
# batch 3 --- Loss: 0.2475
# batch 4 --- Loss: 0.2005
# batch 5 --- Loss: 0.2123
# batch 6 --- Loss: 0.1903
# batch 7 --- Loss: 0.2219
# batch 8 --- Loss: 0.3684
# batch 9 --- Loss: 0.3172
# batch 10 --- Loss: 0.1683
# batch 11 --- Loss: 0.1721
# batch 12 --- Loss: 0.2725
# batch 13 --- Loss: 0.2141
# batch 14 --- Loss: 0.3628
# batch 15 --- Loss: 0.1836
# batch 16 --- Loss: 0.2493
# batch 17 --- Loss: 0.2093
# batch 18 --- Loss: 0.2962
# batch 19 --- Loss: 0.3024
# batch 20 --- Loss: 0.2791
# batch 21 --- Loss: 0.2430
# batch 22 --- Loss: 0.2806
# batch 23 --- Loss: 0.2536
# batch 24 --- Loss: 0.3529
# batch 25 --- Loss: 0.2724
# batch 26 --- Loss: 0.1674
# batch 27 --- Loss: 0.2534
# batch 28 --- Loss: 0.2297
# batch 29 --- Loss: 0.3024
# batch 30 --- Loss: 0.2162
# batch 31 --- Loss: 0.1982
# batch 32 --- Loss: 0.1425
# batch 33 --- Loss: 0.1720
# batch 34 --- Loss: 0.3522
# batch 35 --- Loss: 0.3072
# batch 36 --- Loss: 0.2379
# batch 37 --- Loss: 0.2210
# batch 38 --- Loss: 0.3026
# batch 39 --- Loss: 0.2570
# batch 40 --- Loss: 0.1990
# batch 41 --- Loss: 0.2299
# batch 42 --- Loss: 0.1981
# batch 43 --- Loss: 0.2430
# batch 44 --- Loss: 0.2047
# Epoch 6 / 100 --- Loss: 0.2443
# Accuracy: 0.4197 ---- Loss: 0.5341
# batch 0 --- Loss: 0.2651
# batch 1 --- Loss: 0.4258
# batch 2 --- Loss: 0.2727
# batch 3 --- Loss: 0.3567
# batch 4 --- Loss: 0.2863
# batch 5 --- Loss: 0.2298
# batch 6 --- Loss: 0.2112
# batch 7 --- Loss: 0.2383
# batch 8 --- Loss: 0.2353
# batch 9 --- Loss: 0.2157
# batch 10 --- Loss: 0.2209
# batch 11 --- Loss: 0.3422
# batch 12 --- Loss: 0.2142
# batch 13 --- Loss: 0.2250
# batch 14 --- Loss: 0.2652
# batch 15 --- Loss: 0.1901
# batch 16 --- Loss: 0.2205
# batch 17 --- Loss: 0.3810
# batch 18 --- Loss: 0.1983
# batch 19 --- Loss: 0.1956
# batch 20 --- Loss: 0.2449
# batch 21 --- Loss: 0.3796
# batch 22 --- Loss: 0.2736
# batch 23 --- Loss: 0.1881
# batch 24 --- Loss: 0.1739
# batch 25 --- Loss: 0.2317
# batch 26 --- Loss: 0.2099
# batch 27 --- Loss: 0.3679
# batch 28 --- Loss: 0.2645
# batch 29 --- Loss: 0.2845
# batch 30 --- Loss: 0.2538
# batch 31 --- Loss: 0.2195
# batch 32 --- Loss: 0.1519
# batch 33 --- Loss: 0.2252
# batch 34 --- Loss: 0.2056
# batch 35 --- Loss: 0.2002
# batch 36 --- Loss: 0.1890
# batch 37 --- Loss: 0.3067
# batch 38 --- Loss: 0.2261
# batch 39 --- Loss: 0.2538
# batch 40 --- Loss: 0.1884
# batch 41 --- Loss: 0.2314
# batch 42 --- Loss: 0.1816
# batch 43 --- Loss: 0.2814
# batch 44 --- Loss: 0.3562
# Epoch 7 / 100 --- Loss: 0.2507
# Accuracy: 0.8174 ---- Loss: 0.2080
# batch 0 --- Loss: 0.1806
# batch 1 --- Loss: 0.1724
# batch 2 --- Loss: 0.2908
# batch 3 --- Loss: 0.3382
# batch 4 --- Loss: 0.2215
# batch 5 --- Loss: 0.3632
# batch 6 --- Loss: 0.2455
# batch 7 --- Loss: 0.2510
# batch 8 --- Loss: 0.2009
# batch 9 --- Loss: 0.2435
# batch 10 --- Loss: 0.2635
# batch 11 --- Loss: 0.2660
# batch 12 --- Loss: 0.2603
# batch 13 --- Loss: 0.2594
# batch 14 --- Loss: 0.3609
# batch 15 --- Loss: 0.3409
# batch 16 --- Loss: 0.2532
# batch 17 --- Loss: 0.2518
# batch 18 --- Loss: 0.2102
# batch 19 --- Loss: 0.2438
# batch 20 --- Loss: 0.2140
# batch 21 --- Loss: 0.1916
# batch 22 --- Loss: 0.2405
# batch 23 --- Loss: 0.2025
# batch 24 --- Loss: 0.1758
# batch 25 --- Loss: 0.2213
# batch 26 --- Loss: 0.1804
# batch 27 --- Loss: 0.2471
# batch 28 --- Loss: 0.2055
# batch 29 --- Loss: 0.1874
# batch 30 --- Loss: 0.1481
# batch 31 --- Loss: 0.1835
# batch 32 --- Loss: 0.4008
# batch 33 --- Loss: 0.2153
# batch 34 --- Loss: 0.4047
# batch 35 --- Loss: 0.3224
# batch 36 --- Loss: 0.3577
# batch 37 --- Loss: 0.1878
# batch 38 --- Loss: 0.2895
# batch 39 --- Loss: 0.2795
# batch 40 --- Loss: 0.3060
# batch 41 --- Loss: 0.3271
# batch 42 --- Loss: 0.2394
# batch 43 --- Loss: 0.3099
# batch 44 --- Loss: 0.2837
# Epoch 8 / 100 --- Loss: 0.2564
# Accuracy: 0.5799 ---- Loss: 0.4330
# batch 0 --- Loss: 0.2384
# batch 1 --- Loss: 0.2416
# batch 2 --- Loss: 0.2632
# batch 3 --- Loss: 0.2114
# batch 4 --- Loss: 0.4291
# batch 5 --- Loss: 0.2056
# batch 6 --- Loss: 0.1955
# batch 7 --- Loss: 0.2601
# batch 8 --- Loss: 0.2029
# batch 9 --- Loss: 0.2291
# batch 10 --- Loss: 0.1861
# batch 11 --- Loss: 0.2928
# batch 12 --- Loss: 0.3579
# batch 13 --- Loss: 0.3521
# batch 14 --- Loss: 0.1850
# batch 15 --- Loss: 0.1841
# batch 16 --- Loss: 0.2508
# batch 17 --- Loss: 0.1976
# batch 18 --- Loss: 0.3184
# batch 19 --- Loss: 0.2537
# batch 20 --- Loss: 0.3063
# batch 21 --- Loss: 0.1669
# batch 22 --- Loss: 0.3588
# batch 23 --- Loss: 0.1862
# batch 24 --- Loss: 0.2250
# batch 25 --- Loss: 0.3079
# batch 26 --- Loss: 0.2879
# batch 27 --- Loss: 0.2524
# batch 28 --- Loss: 0.1989
# batch 29 --- Loss: 0.2738
# batch 30 --- Loss: 0.2170
# batch 31 --- Loss: 0.2102
# batch 32 --- Loss: 0.2634
# batch 33 --- Loss: 0.2565
# batch 34 --- Loss: 0.1947
# batch 35 --- Loss: 0.2283
# batch 36 --- Loss: 0.2395
# batch 37 --- Loss: 0.2850
# batch 38 --- Loss: 0.1748
# batch 39 --- Loss: 0.2147
# batch 40 --- Loss: 0.4236
# batch 41 --- Loss: 0.2830
# batch 42 --- Loss: 0.2324
# batch 43 --- Loss: 0.2365
# batch 44 --- Loss: 0.1781
# Epoch 9 / 100 --- Loss: 0.2502
# Accuracy: 0.8284 ---- Loss: 0.2195
# batch 0 --- Loss: 0.2232
# batch 1 --- Loss: 0.2179
# batch 2 --- Loss: 0.3156
# batch 3 --- Loss: 0.2264
# batch 4 --- Loss: 0.1995
# batch 5 --- Loss: 0.3798
# batch 6 --- Loss: 0.2525
# batch 7 --- Loss: 0.1337
# batch 8 --- Loss: 0.2078
# batch 9 --- Loss: 0.1572
# batch 10 --- Loss: 0.2155
# batch 11 --- Loss: 0.1753
# batch 12 --- Loss: 0.2070
# batch 13 --- Loss: 0.2016
# batch 14 --- Loss: 0.2498
# batch 15 --- Loss: 0.2088
# batch 16 --- Loss: 0.5699
# batch 17 --- Loss: 0.2557
# batch 18 --- Loss: 0.2303
# batch 19 --- Loss: 0.3574
# batch 20 --- Loss: 0.2191
# batch 21 --- Loss: 0.2278
# batch 22 --- Loss: 0.2071
# batch 23 --- Loss: 0.2110
# batch 24 --- Loss: 0.3109
# batch 25 --- Loss: 0.2089
# batch 26 --- Loss: 0.1933
# batch 27 --- Loss: 0.2900
# batch 28 --- Loss: 0.2820
# batch 29 --- Loss: 0.2013
# batch 30 --- Loss: 0.2911
# batch 31 --- Loss: 0.3619
# batch 32 --- Loss: 0.2474
# batch 33 --- Loss: 0.2121
# batch 34 --- Loss: 0.2572
# batch 35 --- Loss: 0.1835
# batch 36 --- Loss: 0.3815
# batch 37 --- Loss: 0.2807
# batch 38 --- Loss: 0.3399
# batch 39 --- Loss: 0.2810
# batch 40 --- Loss: 0.2092
# batch 41 --- Loss: 0.1948
# batch 42 --- Loss: 0.3092
# batch 43 --- Loss: 0.2144
# batch 44 --- Loss: 0.2775
# Epoch 10 / 100 --- Loss: 0.2528
# Accuracy: 0.7149 ---- Loss: 0.2800
# batch 0 --- Loss: 0.1823
# batch 1 --- Loss: 0.2385
# batch 2 --- Loss: 0.3000
# batch 3 --- Loss: 0.2042
# batch 4 --- Loss: 0.2301
# batch 5 --- Loss: 0.2371
# batch 6 --- Loss: 0.4608
# batch 7 --- Loss: 0.1698
# batch 8 --- Loss: 0.2490
# batch 9 --- Loss: 0.3133
# batch 10 --- Loss: 0.1783
# batch 11 --- Loss: 0.2149
# batch 12 --- Loss: 0.4484
# batch 13 --- Loss: 0.3251
# batch 14 --- Loss: 0.2508
# batch 15 --- Loss: 0.2422
# batch 16 --- Loss: 0.1804
# batch 17 --- Loss: 0.1966
# batch 18 --- Loss: 0.3093
# batch 19 --- Loss: 0.2380
# batch 20 --- Loss: 0.2926
# batch 21 --- Loss: 0.1822
# batch 22 --- Loss: 0.2025
# batch 23 --- Loss: 0.1911
# batch 24 --- Loss: 0.2680
# batch 25 --- Loss: 0.4436
# batch 26 --- Loss: 0.2247
# batch 27 --- Loss: 0.2685
# batch 28 --- Loss: 0.2348
# batch 29 --- Loss: 0.1637
# batch 30 --- Loss: 0.3801
# batch 31 --- Loss: 0.3531
# batch 32 --- Loss: 0.2337
# batch 33 --- Loss: 0.2008
# batch 34 --- Loss: 0.2029
# batch 35 --- Loss: 0.2166
# batch 36 --- Loss: 0.4025
# batch 37 --- Loss: 0.2128
# batch 38 --- Loss: 0.2360
# batch 39 --- Loss: 0.2193
# batch 40 --- Loss: 0.2054
# batch 41 --- Loss: 0.1852
# batch 42 --- Loss: 0.2903
# batch 43 --- Loss: 0.3322
# batch 44 --- Loss: 0.2284
# Epoch 11 / 100 --- Loss: 0.2564
# Accuracy: 0.7079 ---- Loss: 0.2639
# batch 0 --- Loss: 0.2690
# batch 1 --- Loss: 0.2209
# batch 2 --- Loss: 0.2438
# batch 3 --- Loss: 0.1925
# batch 4 --- Loss: 0.3325
# batch 5 --- Loss: 0.1844
# batch 6 --- Loss: 0.2712
# batch 7 --- Loss: 0.1933
# batch 8 --- Loss: 0.1925
# batch 9 --- Loss: 0.2347
# batch 10 --- Loss: 0.1660
# batch 11 --- Loss: 0.3150
# batch 12 --- Loss: 0.2676
# batch 13 --- Loss: 0.2161
# batch 14 --- Loss: 0.2786
# batch 15 --- Loss: 0.2298
# batch 16 --- Loss: 0.2747
# batch 17 --- Loss: 0.1855
# batch 18 --- Loss: 0.1491
# batch 19 --- Loss: 0.3012
# batch 20 --- Loss: 0.2442
# batch 21 --- Loss: 0.1984
# batch 22 --- Loss: 0.3381
# batch 23 --- Loss: 0.2502
# batch 24 --- Loss: 0.1790
# batch 25 --- Loss: 0.2482
# batch 26 --- Loss: 0.3820
# batch 27 --- Loss: 0.1752
# batch 28 --- Loss: 0.3985
# batch 29 --- Loss: 0.2745
# batch 30 --- Loss: 0.2084
# batch 31 --- Loss: 0.2514
# batch 32 --- Loss: 0.1568
# batch 33 --- Loss: 0.2562
# batch 34 --- Loss: 0.4089
# batch 35 --- Loss: 0.2192
# batch 36 --- Loss: 0.2164
# batch 37 --- Loss: 0.2900
# batch 38 --- Loss: 0.3314
# batch 39 --- Loss: 0.2124
# batch 40 --- Loss: 0.2647
# batch 41 --- Loss: 0.2857
# batch 42 --- Loss: 0.2547
# batch 43 --- Loss: 0.2536
# batch 44 --- Loss: 0.1907
# Epoch 12 / 100 --- Loss: 0.2490
# Accuracy: 0.8290 ---- Loss: 0.2179
# batch 0 --- Loss: 0.2408
# batch 1 --- Loss: 0.4637
# batch 2 --- Loss: 0.2037
# batch 3 --- Loss: 0.1666
# batch 4 --- Loss: 0.2044
# batch 5 --- Loss: 0.2435
# batch 6 --- Loss: 0.2360
# batch 7 --- Loss: 0.2515
# batch 8 --- Loss: 0.3010
# batch 9 --- Loss: 0.2319
# batch 10 --- Loss: 0.2018
# batch 11 --- Loss: 0.3145
# batch 12 --- Loss: 0.3920
# batch 13 --- Loss: 0.1989
# batch 14 --- Loss: 0.2617
# batch 15 --- Loss: 0.2140
# batch 16 --- Loss: 0.2687
# batch 17 --- Loss: 0.2797
# batch 18 --- Loss: 0.1804
# batch 19 --- Loss: 0.2902
# batch 20 --- Loss: 0.1831
# batch 21 --- Loss: 0.3570
# batch 22 --- Loss: 0.3261
# batch 23 --- Loss: 0.3299
# batch 24 --- Loss: 0.1846
# batch 25 --- Loss: 0.2420
# batch 26 --- Loss: 0.1959
# batch 27 --- Loss: 0.2164
# batch 28 --- Loss: 0.1857
# batch 29 --- Loss: 0.2906
# batch 30 --- Loss: 0.3247
# batch 31 --- Loss: 0.2945
# batch 32 --- Loss: 0.2038
# batch 33 --- Loss: 0.2738
# batch 34 --- Loss: 0.2305
# batch 35 --- Loss: 0.1952
# batch 36 --- Loss: 0.2081
# batch 37 --- Loss: 0.3581
# batch 38 --- Loss: 0.2119
# batch 39 --- Loss: 0.1995
# batch 40 --- Loss: 0.2263
# batch 41 --- Loss: 0.2141
# batch 42 --- Loss: 0.1588
# batch 43 --- Loss: 0.4264
# batch 44 --- Loss: 0.2137
# Epoch 13 / 100 --- Loss: 0.2532
# Accuracy: 0.7996 ---- Loss: 0.2335
# batch 0 --- Loss: 0.2136
# batch 1 --- Loss: 0.2346
# batch 2 --- Loss: 0.1731
# batch 3 --- Loss: 0.1694
# batch 4 --- Loss: 0.2401
# batch 5 --- Loss: 0.2908
# batch 6 --- Loss: 0.2270
# batch 7 --- Loss: 0.2319
# batch 8 --- Loss: 0.4124
# batch 9 --- Loss: 0.2643
# batch 10 --- Loss: 0.1966
# batch 11 --- Loss: 0.2444
# batch 12 --- Loss: 0.3070
# batch 13 --- Loss: 0.1895
# batch 14 --- Loss: 0.1874
# batch 15 --- Loss: 0.3077
# batch 16 --- Loss: 0.1957
# batch 17 --- Loss: 0.1808
# batch 18 --- Loss: 0.2543
# batch 19 --- Loss: 0.3064
# batch 20 --- Loss: 0.2405
# batch 21 --- Loss: 0.2912
# batch 22 --- Loss: 0.2973
# batch 23 --- Loss: 0.2120
# batch 24 --- Loss: 0.2289
# batch 25 --- Loss: 0.2301
# batch 26 --- Loss: 0.2980
# batch 27 --- Loss: 0.2951
# batch 28 --- Loss: 0.2493
# batch 29 --- Loss: 0.2396
# batch 30 --- Loss: 0.2288
# batch 31 --- Loss: 0.2635
# batch 32 --- Loss: 0.2234
# batch 33 --- Loss: 0.4048
# batch 34 --- Loss: 0.2165
# batch 35 --- Loss: 0.1722
# batch 36 --- Loss: 0.2528
# batch 37 --- Loss: 0.5271
# batch 38 --- Loss: 0.3477
# batch 39 --- Loss: 0.2417
# batch 40 --- Loss: 0.2980
# batch 41 --- Loss: 0.2975
# batch 42 --- Loss: 0.2550
# batch 43 --- Loss: 0.2469
# batch 44 --- Loss: 0.2571
# Epoch 14 / 100 --- Loss: 0.2587
# Accuracy: 0.5517 ---- Loss: 0.3233
# batch 0 --- Loss: 0.2592
# batch 1 --- Loss: 0.2619
# batch 2 --- Loss: 0.2078
# batch 3 --- Loss: 0.2434
# batch 4 --- Loss: 0.2274
# batch 5 --- Loss: 0.2491
# batch 6 --- Loss: 0.2830
# batch 7 --- Loss: 0.2335
# batch 8 --- Loss: 0.1987
# batch 9 --- Loss: 0.2626
# batch 10 --- Loss: 0.4031
# batch 11 --- Loss: 0.3138
# batch 12 --- Loss: 0.3793
# batch 13 --- Loss: 0.3905
# batch 14 --- Loss: 0.2086
# batch 15 --- Loss: 0.2124
# batch 16 --- Loss: 0.2143
# batch 17 --- Loss: 0.3260
# batch 18 --- Loss: 0.2408
# batch 19 --- Loss: 0.2550
# batch 20 --- Loss: 0.2221
# batch 21 --- Loss: 0.1677
# batch 22 --- Loss: 0.2303
# batch 23 --- Loss: 0.3144
# batch 24 --- Loss: 0.2321
# batch 25 --- Loss: 0.2097
# batch 26 --- Loss: 0.1964
# batch 27 --- Loss: 0.2009
# batch 28 --- Loss: 0.2767
# batch 29 --- Loss: 0.2580
# batch 30 --- Loss: 0.2804
# batch 31 --- Loss: 0.1433
# batch 32 --- Loss: 0.2817
# batch 33 --- Loss: 0.2018
# batch 34 --- Loss: 0.1667
# batch 35 --- Loss: 0.2215
# batch 36 --- Loss: 0.2346
# batch 37 --- Loss: 0.3694
# batch 38 --- Loss: 0.1856
# batch 39 --- Loss: 0.2530
# batch 40 --- Loss: 0.2423
# batch 41 --- Loss: 0.1854
# batch 42 --- Loss: 0.2225
# batch 43 --- Loss: 0.2018
# batch 44 --- Loss: 0.2821
# Epoch 15 / 100 --- Loss: 0.2478
# Accuracy: 0.8102 ---- Loss: 0.2519
# batch 0 --- Loss: 0.4164
# batch 1 --- Loss: 0.2143
# batch 2 --- Loss: 0.2922
# batch 3 --- Loss: 0.3206
# batch 4 --- Loss: 0.4016
# batch 5 --- Loss: 0.2821
# batch 6 --- Loss: 0.1464
# batch 7 --- Loss: 0.1920
# batch 8 --- Loss: 0.3044
# batch 9 --- Loss: 0.2187
# batch 10 --- Loss: 0.2678
# batch 11 --- Loss: 0.2283
# batch 12 --- Loss: 0.2606
# batch 13 --- Loss: 0.2168
# batch 14 --- Loss: 0.2353
# batch 15 --- Loss: 0.2192
# batch 16 --- Loss: 0.1944
# batch 17 --- Loss: 0.1797
# batch 18 --- Loss: 0.2726
# batch 19 --- Loss: 0.2368
# batch 20 --- Loss: 0.1815
# batch 21 --- Loss: 0.1722
# batch 22 --- Loss: 0.3018
# batch 23 --- Loss: 0.2778
# batch 24 --- Loss: 0.2256
# batch 25 --- Loss: 0.2193
# batch 26 --- Loss: 0.1815
# batch 27 --- Loss: 0.1389
# batch 28 --- Loss: 0.1632
# batch 29 --- Loss: 0.2206
# batch 30 --- Loss: 0.3492
# batch 31 --- Loss: 0.1866
# batch 32 --- Loss: 0.5651
# batch 33 --- Loss: 0.2318
# batch 34 --- Loss: 0.2388
# batch 35 --- Loss: 0.2435
# batch 36 --- Loss: 0.2258
# batch 37 --- Loss: 0.1662
# batch 38 --- Loss: 0.1920
# batch 39 --- Loss: 0.3821
# batch 40 --- Loss: 0.1927
# batch 41 --- Loss: 0.1781
# batch 42 --- Loss: 0.2938
# batch 43 --- Loss: 0.3074
# batch 44 --- Loss: 0.2177
# Epoch 16 / 100 --- Loss: 0.2478
# Accuracy: 0.8130 ---- Loss: 0.2158
# batch 0 --- Loss: 0.1924
# batch 1 --- Loss: 0.1866
# batch 2 --- Loss: 0.2847
# batch 3 --- Loss: 0.2198
# batch 4 --- Loss: 0.3229
# batch 5 --- Loss: 0.1923
# batch 6 --- Loss: 0.3389
# batch 7 --- Loss: 0.1716
# batch 8 --- Loss: 0.3335
# batch 9 --- Loss: 0.2479
# batch 10 --- Loss: 0.1694
# batch 11 --- Loss: 0.1771
# batch 12 --- Loss: 0.3070
# batch 13 --- Loss: 0.1652
# batch 14 --- Loss: 0.1557
# batch 15 --- Loss: 0.3447
# batch 16 --- Loss: 0.2562
# batch 17 --- Loss: 0.3097
# batch 18 --- Loss: 0.1729
# batch 19 --- Loss: 0.3077
# batch 20 --- Loss: 0.2407
# batch 21 --- Loss: 0.3102
# batch 22 --- Loss: 0.2253
# batch 23 --- Loss: 0.2012
# batch 24 --- Loss: 0.2128
# batch 25 --- Loss: 0.3163
# batch 26 --- Loss: 0.2380
# batch 27 --- Loss: 0.2732
# batch 28 --- Loss: 0.2445
# batch 29 --- Loss: 0.2570
# batch 30 --- Loss: 0.2088
# batch 31 --- Loss: 0.2172
# batch 32 --- Loss: 0.2448
# batch 33 --- Loss: 0.3195
# batch 34 --- Loss: 0.2094
# batch 35 --- Loss: 0.2045
# batch 36 --- Loss: 0.4189
# batch 37 --- Loss: 0.2139
# batch 38 --- Loss: 0.1806
# batch 39 --- Loss: 0.1569
# batch 40 --- Loss: 0.1640
# batch 41 --- Loss: 0.2153
# batch 42 --- Loss: 0.1860
# batch 43 --- Loss: 0.2056
# batch 44 --- Loss: 0.3595
# Epoch 17 / 100 --- Loss: 0.2418
# Accuracy: 0.7844 ---- Loss: 0.2307
# batch 0 --- Loss: 0.2989
# batch 1 --- Loss: 0.1726
# batch 2 --- Loss: 0.2402
# batch 3 --- Loss: 0.3281
# batch 4 --- Loss: 0.1435
# batch 5 --- Loss: 0.1715
# batch 6 --- Loss: 0.2165
# batch 7 --- Loss: 0.2956
# batch 8 --- Loss: 0.3848
# batch 9 --- Loss: 0.2744
# batch 10 --- Loss: 0.1586
# batch 11 --- Loss: 0.1809
# batch 12 --- Loss: 0.2195
# batch 13 --- Loss: 0.2423
# batch 14 --- Loss: 0.2520
# batch 15 --- Loss: 0.2601
# batch 16 --- Loss: 0.3125
# batch 17 --- Loss: 0.2186
# batch 18 --- Loss: 0.2810
# batch 19 --- Loss: 0.1643
# batch 20 --- Loss: 0.2946
# batch 21 --- Loss: 0.1824
# batch 22 --- Loss: 0.2036
# batch 23 --- Loss: 0.2166
# batch 24 --- Loss: 0.2672
# batch 25 --- Loss: 0.1880
# batch 26 --- Loss: 0.3305
# batch 27 --- Loss: 0.2412
# batch 28 --- Loss: 0.2199
# batch 29 --- Loss: 0.2834
# batch 30 --- Loss: 0.3790
# batch 31 --- Loss: 0.1974
# batch 32 --- Loss: 0.2282
# batch 33 --- Loss: 0.2229
# batch 34 --- Loss: 0.2837
# batch 35 --- Loss: 0.1868
# batch 36 --- Loss: 0.2708
# batch 37 --- Loss: 0.3329
# batch 38 --- Loss: 0.2708
# batch 39 --- Loss: 0.1505
# batch 40 --- Loss: 0.2048
# batch 41 --- Loss: 0.1897
# batch 42 --- Loss: 0.2383
# batch 43 --- Loss: 0.2684
# batch 44 --- Loss: 0.4322
# Epoch 18 / 100 --- Loss: 0.2467
# Accuracy: 0.8069 ---- Loss: 0.2162
# batch 0 --- Loss: 0.2240
# batch 1 --- Loss: 0.4101
# batch 2 --- Loss: 0.1991
# batch 3 --- Loss: 0.2179
# batch 4 --- Loss: 0.2198
# batch 5 --- Loss: 0.2168
# batch 6 --- Loss: 0.2015
# batch 7 --- Loss: 0.2174
# batch 8 --- Loss: 0.1484
# batch 9 --- Loss: 0.1917
# batch 10 --- Loss: 0.2777
# batch 11 --- Loss: 0.2690
# batch 12 --- Loss: 0.2506
# batch 13 --- Loss: 0.1796
# batch 14 --- Loss: 0.3059
# batch 15 --- Loss: 0.1986
# batch 16 --- Loss: 0.2561
# batch 17 --- Loss: 0.2967
# batch 18 --- Loss: 0.3470
# batch 19 --- Loss: 0.2189
# batch 20 --- Loss: 0.2250
# batch 21 --- Loss: 0.2426
# batch 22 --- Loss: 0.1931
# batch 23 --- Loss: 0.2203
# batch 24 --- Loss: 0.2548
# batch 25 --- Loss: 0.2774
# batch 26 --- Loss: 0.1985
# batch 27 --- Loss: 0.2830
# batch 28 --- Loss: 0.2722
# batch 29 --- Loss: 0.2726
# batch 30 --- Loss: 0.2271
# batch 31 --- Loss: 0.2782
# batch 32 --- Loss: 0.2011
# batch 33 --- Loss: 0.3128
# batch 34 --- Loss: 0.2862
# batch 35 --- Loss: 0.1936
# batch 36 --- Loss: 0.1990
# batch 37 --- Loss: 0.3573
# batch 38 --- Loss: 0.1842
# batch 39 --- Loss: 0.1886
# batch 40 --- Loss: 0.2325
# batch 41 --- Loss: 0.1736
# batch 42 --- Loss: 0.4470
# batch 43 --- Loss: 0.2571
# batch 44 --- Loss: 0.2788
# Epoch 19 / 100 --- Loss: 0.2467
# Accuracy: 0.7851 ---- Loss: 0.2280
# batch 0 --- Loss: 0.1419
# batch 1 --- Loss: 0.2171
# batch 2 --- Loss: 0.3090
# batch 3 --- Loss: 0.2812
# batch 4 --- Loss: 0.2527
# batch 5 --- Loss: 0.1742
# batch 6 --- Loss: 0.2319
# batch 7 --- Loss: 0.2099
# batch 8 --- Loss: 0.3199
# batch 9 --- Loss: 0.2283
# batch 10 --- Loss: 0.1853
# batch 11 --- Loss: 0.2754
# batch 12 --- Loss: 0.3193
# batch 13 --- Loss: 0.2009
# batch 14 --- Loss: 0.2027
# batch 15 --- Loss: 0.2355
# batch 16 --- Loss: 0.2332
# batch 17 --- Loss: 0.2326
# batch 18 --- Loss: 0.2035
# batch 19 --- Loss: 0.1482
# batch 20 --- Loss: 0.2436
# batch 21 --- Loss: 0.2458
# batch 22 --- Loss: 0.2440
# batch 23 --- Loss: 0.3159
# batch 24 --- Loss: 0.2684
# batch 25 --- Loss: 0.2002
# batch 26 --- Loss: 0.1699
# batch 27 --- Loss: 0.2877
# batch 28 --- Loss: 0.2656
# batch 29 --- Loss: 0.1841
# batch 30 --- Loss: 0.3225
# batch 31 --- Loss: 0.2651
# batch 32 --- Loss: 0.2754
# batch 33 --- Loss: 0.1981
# batch 34 --- Loss: 0.2620
# batch 35 --- Loss: 0.2058
# batch 36 --- Loss: 0.1739
# batch 37 --- Loss: 0.1297
# batch 38 --- Loss: 0.1754
# batch 39 --- Loss: 0.3777
# batch 40 --- Loss: 0.1697
# batch 41 --- Loss: 0.3188
# batch 42 --- Loss: 0.3831
# batch 43 --- Loss: 0.2005
# batch 44 --- Loss: 0.1891
# Epoch 20 / 100 --- Loss: 0.2372
# Accuracy: 0.7260 ---- Loss: 0.2788
# batch 0 --- Loss: 0.2634
# batch 1 --- Loss: 0.1915
# batch 2 --- Loss: 0.3606
# batch 3 --- Loss: 0.2816
# batch 4 --- Loss: 0.2739
# batch 5 --- Loss: 0.2111
# batch 6 --- Loss: 0.2050
# batch 7 --- Loss: 0.2001
# batch 8 --- Loss: 0.2821
# batch 9 --- Loss: 0.1846
# batch 10 --- Loss: 0.1953
# batch 11 --- Loss: 0.4673
# batch 12 --- Loss: 0.3677
# batch 13 --- Loss: 0.1731
# batch 14 --- Loss: 0.1668
# batch 15 --- Loss: 0.2055
# batch 16 --- Loss: 0.2139
# batch 17 --- Loss: 0.2084
# batch 18 --- Loss: 0.2159
# batch 19 --- Loss: 0.2629
# batch 20 --- Loss: 0.2535
# batch 21 --- Loss: 0.2966
# batch 22 --- Loss: 0.2373
# batch 23 --- Loss: 0.2725
# batch 24 --- Loss: 0.2005
# batch 25 --- Loss: 0.1852
# batch 26 --- Loss: 0.2273
# batch 27 --- Loss: 0.2771
# batch 28 --- Loss: 0.1869
# batch 29 --- Loss: 0.2194
# batch 30 --- Loss: 0.2632
# batch 31 --- Loss: 0.2965
# batch 32 --- Loss: 0.2368
# batch 33 --- Loss: 0.1791
# batch 34 --- Loss: 0.1832
# batch 35 --- Loss: 0.1795
# batch 36 --- Loss: 0.4024
# batch 37 --- Loss: 0.2980
# batch 38 --- Loss: 0.2358
# batch 39 --- Loss: 0.2124
# batch 40 --- Loss: 0.1974
# batch 41 --- Loss: 0.1691
# batch 42 --- Loss: 0.3483
# batch 43 --- Loss: 0.3113
# batch 44 --- Loss: 0.2346
# Epoch 21 / 100 --- Loss: 0.2452
# Accuracy: 0.4197 ---- Loss: 0.4448
# batch 0 --- Loss: 0.2134
# batch 1 --- Loss: 0.2614
# batch 2 --- Loss: 0.2758
# batch 3 --- Loss: 0.3182
# batch 4 --- Loss: 0.1917
# batch 5 --- Loss: 0.2082
# batch 6 --- Loss: 0.3943
# batch 7 --- Loss: 0.2363
# batch 8 --- Loss: 0.1839
# batch 9 --- Loss: 0.3203
# batch 10 --- Loss: 0.3073
# batch 11 --- Loss: 0.2297
# batch 12 --- Loss: 0.2896
# batch 13 --- Loss: 0.2868
# batch 14 --- Loss: 0.3002
# batch 15 --- Loss: 0.1944
# batch 16 --- Loss: 0.1907
# batch 17 --- Loss: 0.1835
# batch 18 --- Loss: 0.2839
# batch 19 --- Loss: 0.1958
# batch 20 --- Loss: 0.2858
# batch 21 --- Loss: 0.3336
# batch 22 --- Loss: 0.2227
# batch 23 --- Loss: 0.3006
# batch 24 --- Loss: 0.1776
# batch 25 --- Loss: 0.2940
# batch 26 --- Loss: 0.1677
# batch 27 --- Loss: 0.1854
# batch 28 --- Loss: 0.2127
# batch 29 --- Loss: 0.2264
# batch 30 --- Loss: 0.2047
# batch 31 --- Loss: 0.3168
# batch 32 --- Loss: 0.2412
# batch 33 --- Loss: 0.1872
# batch 34 --- Loss: 0.2279
# batch 35 --- Loss: 0.3120
# batch 36 --- Loss: 0.2693
# batch 37 --- Loss: 0.1852
# batch 38 --- Loss: 0.1848
# batch 39 --- Loss: 0.2919
# batch 40 --- Loss: 0.1842
# batch 41 --- Loss: 0.4085
# batch 42 --- Loss: 0.2460
# batch 43 --- Loss: 0.1643
# batch 44 --- Loss: 0.2940
# Epoch 22 / 100 --- Loss: 0.2487
# Accuracy: 0.8281 ---- Loss: 0.2172
# batch 0 --- Loss: 0.1886
# batch 1 --- Loss: 0.2540
# batch 2 --- Loss: 0.2965
# batch 3 --- Loss: 0.4697
# batch 4 --- Loss: 0.2950
# batch 5 --- Loss: 0.2048
# batch 6 --- Loss: 0.2203
# batch 7 --- Loss: 0.3123
# batch 8 --- Loss: 0.2559
# batch 9 --- Loss: 0.1875
# batch 10 --- Loss: 0.2978
# batch 11 --- Loss: 0.2335
# batch 12 --- Loss: 0.3824
# batch 13 --- Loss: 0.2609
# batch 14 --- Loss: 0.2203
# batch 15 --- Loss: 0.1860
# batch 16 --- Loss: 0.2615
# batch 17 --- Loss: 0.2288
# batch 18 --- Loss: 0.1865
# batch 19 --- Loss: 0.2070
# batch 20 --- Loss: 0.2756
# batch 21 --- Loss: 0.2227
# batch 22 --- Loss: 0.2306
# batch 23 --- Loss: 0.3896
# batch 24 --- Loss: 0.3520
# batch 25 --- Loss: 0.3246
# batch 26 --- Loss: 0.2128
# batch 27 --- Loss: 0.1884
# batch 28 --- Loss: 0.2709
# batch 29 --- Loss: 0.2423
# batch 30 --- Loss: 0.3224
# batch 31 --- Loss: 0.1864
# batch 32 --- Loss: 0.1787
# batch 33 --- Loss: 0.1804
# batch 34 --- Loss: 0.2759
# batch 35 --- Loss: 0.2092
# batch 36 --- Loss: 0.1949
# batch 37 --- Loss: 0.2393
# batch 38 --- Loss: 0.2847
# batch 39 --- Loss: 0.1993
# batch 40 --- Loss: 0.3461
# batch 41 --- Loss: 0.1887
# batch 42 --- Loss: 0.1804
# batch 43 --- Loss: 0.1629
# batch 44 --- Loss: 0.1762
# Epoch 23 / 100 --- Loss: 0.2485
# Accuracy: 0.8297 ---- Loss: 0.2063
# batch 0 --- Loss: 0.1581
# batch 1 --- Loss: 0.3520
# batch 2 --- Loss: 0.1775
# batch 3 --- Loss: 0.1680
# batch 4 --- Loss: 0.3721
# batch 5 --- Loss: 0.2531
# batch 6 --- Loss: 0.2767
# batch 7 --- Loss: 0.3735
# batch 8 --- Loss: 0.3846
# batch 9 --- Loss: 0.2845
# batch 10 --- Loss: 0.2130
# batch 11 --- Loss: 0.2668
# batch 12 --- Loss: 0.2246
# batch 13 --- Loss: 0.2599
# batch 14 --- Loss: 0.2488
# batch 15 --- Loss: 0.2110
# batch 16 --- Loss: 0.2851
# batch 17 --- Loss: 0.2008
# batch 18 --- Loss: 0.2104
# batch 19 --- Loss: 0.1707
# batch 20 --- Loss: 0.2975
# batch 21 --- Loss: 0.3065
# batch 22 --- Loss: 0.1805
# batch 23 --- Loss: 0.2710
# batch 24 --- Loss: 0.3142
# batch 25 --- Loss: 0.1777
# batch 26 --- Loss: 0.1790
# batch 27 --- Loss: 0.1730
# batch 28 --- Loss: 0.1854
# batch 29 --- Loss: 0.3434
# batch 30 --- Loss: 0.3732
# batch 31 --- Loss: 0.2009
# batch 32 --- Loss: 0.2420
# batch 33 --- Loss: 0.3675
# batch 34 --- Loss: 0.1806
# batch 35 --- Loss: 0.3303
# batch 36 --- Loss: 0.1811
# batch 37 --- Loss: 0.2836
# batch 38 --- Loss: 0.1646
# batch 39 --- Loss: 0.1528
# batch 40 --- Loss: 0.1832
# batch 41 --- Loss: 0.2121
# batch 42 --- Loss: 0.1643
# batch 43 --- Loss: 0.3041
# batch 44 --- Loss: 0.2789
# Epoch 24 / 100 --- Loss: 0.2475
# Accuracy: 0.8309 ---- Loss: 0.2027
# batch 0 --- Loss: 0.2262
# batch 1 --- Loss: 0.2316
# batch 2 --- Loss: 0.3109
# batch 3 --- Loss: 0.1957
# batch 4 --- Loss: 0.3171
# batch 5 --- Loss: 0.1698
# batch 6 --- Loss: 0.2275
# batch 7 --- Loss: 0.1806
# batch 8 --- Loss: 0.2759
# batch 9 --- Loss: 0.1253
# batch 10 --- Loss: 0.2639
# batch 11 --- Loss: 0.3486
# batch 12 --- Loss: 0.2347
# batch 13 --- Loss: 0.2629
# batch 14 --- Loss: 0.2043
# batch 15 --- Loss: 0.2275
# batch 16 --- Loss: 0.1707
# batch 17 --- Loss: 0.1934
# batch 18 --- Loss: 0.3660
# batch 19 --- Loss: 0.1676
# batch 20 --- Loss: 0.2934
# batch 21 --- Loss: 0.2141
# batch 22 --- Loss: 0.2443
# batch 23 --- Loss: 0.2899
# batch 24 --- Loss: 0.2373
# batch 25 --- Loss: 0.2978
# batch 26 --- Loss: 0.2976
# batch 27 --- Loss: 0.3608
# batch 28 --- Loss: 0.3261
# batch 29 --- Loss: 0.1755
# batch 30 --- Loss: 0.1738
# batch 31 --- Loss: 0.2391
# batch 32 --- Loss: 0.2427
# batch 33 --- Loss: 0.2936
# batch 34 --- Loss: 0.3117
# batch 35 --- Loss: 0.4442
# batch 36 --- Loss: 0.2465
# batch 37 --- Loss: 0.2010
# batch 38 --- Loss: 0.2342
# batch 39 --- Loss: 0.2117
# batch 40 --- Loss: 0.2811
# batch 41 --- Loss: 0.1935
# batch 42 --- Loss: 0.2275
# batch 43 --- Loss: 0.2809
# batch 44 --- Loss: 0.2707
# Epoch 25 / 100 --- Loss: 0.2509
# Accuracy: 0.8160 ---- Loss: 0.2421
# batch 0 --- Loss: 0.2136
# batch 1 --- Loss: 0.1848
# batch 2 --- Loss: 0.2621
# batch 3 --- Loss: 0.3879
# batch 4 --- Loss: 0.4561
# batch 5 --- Loss: 0.2622
# batch 6 --- Loss: 0.1515
# batch 7 --- Loss: 0.2066
# batch 8 --- Loss: 0.2686
# batch 9 --- Loss: 0.1635
# batch 10 --- Loss: 0.2363
# batch 11 --- Loss: 0.3077
# batch 12 --- Loss: 0.1895
# batch 13 --- Loss: 0.3764
# batch 14 --- Loss: 0.1910
# batch 15 --- Loss: 0.1929
# batch 16 --- Loss: 0.1867
# batch 17 --- Loss: 0.3170
# batch 18 --- Loss: 0.2508
# batch 19 --- Loss: 0.1829
# batch 20 --- Loss: 0.3084
# batch 21 --- Loss: 0.2364
# batch 22 --- Loss: 0.3438
# batch 23 --- Loss: 0.3389
# batch 24 --- Loss: 0.2368
# batch 25 --- Loss: 0.2288
# batch 26 --- Loss: 0.2410
# batch 27 --- Loss: 0.2251
# batch 28 --- Loss: 0.3812
# batch 29 --- Loss: 0.3193
# batch 30 --- Loss: 0.2259
# batch 31 --- Loss: 0.2310
# batch 32 --- Loss: 0.2750
# batch 33 --- Loss: 0.1752
# batch 34 --- Loss: 0.2593
# batch 35 --- Loss: 0.2091
# batch 36 --- Loss: 0.2593
# batch 37 --- Loss: 0.2286
# batch 38 --- Loss: 0.2134
# batch 39 --- Loss: 0.2360
# batch 40 --- Loss: 0.3300
# batch 41 --- Loss: 0.1763
# batch 42 --- Loss: 0.2222
# batch 43 --- Loss: 0.2747
# batch 44 --- Loss: 0.2093
# Epoch 26 / 100 --- Loss: 0.2527
# Accuracy: 0.7833 ---- Loss: 0.2563
# batch 0 --- Loss: 0.2301
# batch 1 --- Loss: 0.2276
# batch 2 --- Loss: 0.1612
# batch 3 --- Loss: 0.3135
# batch 4 --- Loss: 0.1653
# batch 5 --- Loss: 0.3455
# batch 6 --- Loss: 0.4057
# batch 7 --- Loss: 0.3081
# batch 8 --- Loss: 0.2792
# batch 9 --- Loss: 0.3617
# batch 10 --- Loss: 0.4375
# batch 11 --- Loss: 0.2454
# batch 12 --- Loss: 0.2858
# batch 13 --- Loss: 0.2503
# batch 14 --- Loss: 0.2750
# batch 15 --- Loss: 0.2281
# batch 16 --- Loss: 0.2671
# batch 17 --- Loss: 0.2880
# batch 18 --- Loss: 0.2199
# batch 19 --- Loss: 0.2098
# batch 20 --- Loss: 0.2745
# batch 21 --- Loss: 0.1839
# batch 22 --- Loss: 0.1988
# batch 23 --- Loss: 0.1730
# batch 24 --- Loss: 0.2523
# batch 25 --- Loss: 0.2549
# batch 26 --- Loss: 0.2814
# batch 27 --- Loss: 0.3072
# batch 28 --- Loss: 0.2362
# batch 29 --- Loss: 0.1832
# batch 30 --- Loss: 0.2771
# batch 31 --- Loss: 0.2797
# batch 32 --- Loss: 0.1812
# batch 33 --- Loss: 0.1908
# batch 34 --- Loss: 0.2371
# batch 35 --- Loss: 0.2424
# batch 36 --- Loss: 0.2480
# batch 37 --- Loss: 0.2578
# batch 38 --- Loss: 0.2241
# batch 39 --- Loss: 0.2179
# batch 40 --- Loss: 0.2649
# batch 41 --- Loss: 0.1950
# batch 42 --- Loss: 0.1808
# batch 43 --- Loss: 0.2637
# batch 44 --- Loss: 0.2424
# Epoch 27 / 100 --- Loss: 0.2523
# Accuracy: 0.8294 ---- Loss: 0.2034
# batch 0 --- Loss: 0.1716
# batch 1 --- Loss: 0.2585
# batch 2 --- Loss: 0.2007
# batch 3 --- Loss: 0.2206
# batch 4 --- Loss: 0.1866
# batch 5 --- Loss: 0.2332
# batch 6 --- Loss: 0.1867
# batch 7 --- Loss: 0.3508
# batch 8 --- Loss: 0.2224
# batch 9 --- Loss: 0.1778
# batch 10 --- Loss: 0.1574
# batch 11 --- Loss: 0.2615
# batch 12 --- Loss: 0.3786
# batch 13 --- Loss: 0.3698
# batch 14 --- Loss: 0.2123
# batch 15 --- Loss: 0.1991
# batch 16 --- Loss: 0.1890
# batch 17 --- Loss: 0.1636
# batch 18 --- Loss: 0.1253
# batch 19 --- Loss: 0.3096
# batch 20 --- Loss: 0.1143
# batch 21 --- Loss: 0.2529
# batch 22 --- Loss: 0.2897
# batch 23 --- Loss: 0.3768
# batch 24 --- Loss: 0.2483
# batch 25 --- Loss: 0.2673
# batch 26 --- Loss: 0.2081
# batch 27 --- Loss: 0.1712
# batch 28 --- Loss: 0.3094
# batch 29 --- Loss: 0.2019
# batch 30 --- Loss: 0.2207
# batch 31 --- Loss: 0.2891
# batch 32 --- Loss: 0.1612
# batch 33 --- Loss: 0.2468
# batch 34 --- Loss: 0.3083
# batch 35 --- Loss: 0.2017
# batch 36 --- Loss: 0.2224
# batch 37 --- Loss: 0.3495
# batch 38 --- Loss: 0.2434
# batch 39 --- Loss: 0.1294
# batch 40 --- Loss: 0.3058
# batch 41 --- Loss: 0.2516
# batch 42 --- Loss: 0.2343
# batch 43 --- Loss: 0.2144
# batch 44 --- Loss: 0.3152
# Epoch 28 / 100 --- Loss: 0.2380
# Accuracy: 0.7936 ---- Loss: 0.2581
# batch 0 --- Loss: 0.3448
# batch 1 --- Loss: 0.2201
# batch 2 --- Loss: 0.2412
# batch 3 --- Loss: 0.2874
# batch 4 --- Loss: 0.3802
# batch 5 --- Loss: 0.1797
# batch 6 --- Loss: 0.1732
# batch 7 --- Loss: 0.2307
# batch 8 --- Loss: 0.2887
# batch 9 --- Loss: 0.2066
# batch 10 --- Loss: 0.2026
# batch 11 --- Loss: 0.3057
# batch 12 --- Loss: 0.2024
# batch 13 --- Loss: 0.1935
# batch 14 --- Loss: 0.2339
# batch 15 --- Loss: 0.1669
# batch 16 --- Loss: 0.2048
# batch 17 --- Loss: 0.2060
# batch 18 --- Loss: 0.3253
# batch 19 --- Loss: 0.1659
# batch 20 --- Loss: 0.2549
# batch 21 --- Loss: 0.2831
# batch 22 --- Loss: 0.2386
# batch 23 --- Loss: 0.2332
# batch 24 --- Loss: 0.1636
# batch 25 --- Loss: 0.3577
# batch 26 --- Loss: 0.2704
# batch 27 --- Loss: 0.2204
# batch 28 --- Loss: 0.1670
# batch 29 --- Loss: 0.2125
# batch 30 --- Loss: 0.1684
# batch 31 --- Loss: 0.2793
# batch 32 --- Loss: 0.2529
# batch 33 --- Loss: 0.1939
# batch 34 --- Loss: 0.3754
# batch 35 --- Loss: 0.1497
# batch 36 --- Loss: 0.3306
# batch 37 --- Loss: 0.3624
# batch 38 --- Loss: 0.3423
# batch 39 --- Loss: 0.2733
# batch 40 --- Loss: 0.3602
# batch 41 --- Loss: 0.1913
# batch 42 --- Loss: 0.1890
# batch 43 --- Loss: 0.2376
# batch 44 --- Loss: 0.1746
# Epoch 29 / 100 --- Loss: 0.2454
# Accuracy: 0.8258 ---- Loss: 0.2383
# batch 0 --- Loss: 0.1880
# batch 1 --- Loss: 0.1764
# batch 2 --- Loss: 0.2612
# batch 3 --- Loss: 0.3439
# batch 4 --- Loss: 0.2382
# batch 5 --- Loss: 0.4708
# batch 6 --- Loss: 0.1998
# batch 7 --- Loss: 0.2276
# batch 8 --- Loss: 0.2006
# batch 9 --- Loss: 0.1853
# batch 10 --- Loss: 0.3004
# batch 11 --- Loss: 0.2662
# batch 12 --- Loss: 0.1943
# batch 13 --- Loss: 0.2665
# batch 14 --- Loss: 0.2079
# batch 15 --- Loss: 0.3250
# batch 16 --- Loss: 0.2178
# batch 17 --- Loss: 0.1800
# batch 18 --- Loss: 0.1899
# batch 19 --- Loss: 0.2373
# batch 20 --- Loss: 0.2325
# batch 21 --- Loss: 0.2534
# batch 22 --- Loss: 0.4544
# batch 23 --- Loss: 0.3338
# batch 24 --- Loss: 0.2007
# batch 25 --- Loss: 0.2710
# batch 26 --- Loss: 0.2241
# batch 27 --- Loss: 0.2812
# batch 28 --- Loss: 0.2041
# batch 29 --- Loss: 0.2287
# batch 30 --- Loss: 0.2919
# batch 31 --- Loss: 0.2411
# batch 32 --- Loss: 0.2240
# batch 33 --- Loss: 0.2340
# batch 34 --- Loss: 0.1935
# batch 35 --- Loss: 0.2771
# batch 36 --- Loss: 0.3946
# batch 37 --- Loss: 0.2795
# batch 38 --- Loss: 0.2803
# batch 39 --- Loss: 0.1882
# batch 40 --- Loss: 0.2280
# batch 41 --- Loss: 0.2549
# batch 42 --- Loss: 0.2209
# batch 43 --- Loss: 0.1845
# batch 44 --- Loss: 0.2555
# Epoch 30 / 100 --- Loss: 0.2513
# Accuracy: 0.7831 ---- Loss: 0.2525
# batch 0 --- Loss: 0.2990
# batch 1 --- Loss: 0.1717
# batch 2 --- Loss: 0.2139
# batch 3 --- Loss: 0.2178
# batch 4 --- Loss: 0.2672
# batch 5 --- Loss: 0.1822
# batch 6 --- Loss: 0.1479
# batch 7 --- Loss: 0.2504
# batch 8 --- Loss: 0.1615
# batch 9 --- Loss: 0.3821
# batch 10 --- Loss: 0.2624
# batch 11 --- Loss: 0.1978
# batch 12 --- Loss: 0.1522
# batch 13 --- Loss: 0.1853
# batch 14 --- Loss: 0.3687
# batch 15 --- Loss: 0.2344
# batch 16 --- Loss: 0.3551
# batch 17 --- Loss: 0.1866
# batch 18 --- Loss: 0.3442
# batch 19 --- Loss: 0.2712
# batch 20 --- Loss: 0.1561
# batch 21 --- Loss: 0.3640
# batch 22 --- Loss: 0.2220
# batch 23 --- Loss: 0.3289
# batch 24 --- Loss: 0.1994
# batch 25 --- Loss: 0.2701
# batch 26 --- Loss: 0.1739
# batch 27 --- Loss: 0.3628
# batch 28 --- Loss: 0.2943
# batch 29 --- Loss: 0.3098
# batch 30 --- Loss: 0.2624
# batch 31 --- Loss: 0.3084
# batch 32 --- Loss: 0.1669
# batch 33 --- Loss: 0.1679
# batch 34 --- Loss: 0.2088
# batch 35 --- Loss: 0.2464
# batch 36 --- Loss: 0.3080
# batch 37 --- Loss: 0.1630
# batch 38 --- Loss: 0.2672
# batch 39 --- Loss: 0.3347
# batch 40 --- Loss: 0.3234
# batch 41 --- Loss: 0.2029
# batch 42 --- Loss: 0.2258
# batch 43 --- Loss: 0.2531
# batch 44 --- Loss: 0.2454
# Epoch 31 / 100 --- Loss: 0.2493
# Accuracy: 0.8255 ---- Loss: 0.2150
# batch 0 --- Loss: 0.3121
# batch 1 --- Loss: 0.1885
# batch 2 --- Loss: 0.3110
# batch 3 --- Loss: 0.1723
# batch 4 --- Loss: 0.2744
# batch 5 --- Loss: 0.2088
# batch 6 --- Loss: 0.2339
# batch 7 --- Loss: 0.2457
# batch 8 --- Loss: 0.2039
# batch 9 --- Loss: 0.1756
# batch 10 --- Loss: 0.2207
# batch 11 --- Loss: 0.2671
# batch 12 --- Loss: 0.1759
# batch 13 --- Loss: 0.2694
# batch 14 --- Loss: 0.1757
# batch 15 --- Loss: 0.2580
# batch 16 --- Loss: 0.3971
# batch 17 --- Loss: 0.2821
# batch 18 --- Loss: 0.1962
# batch 19 --- Loss: 0.4041
# batch 20 --- Loss: 0.2737
# batch 21 --- Loss: 0.2126
# batch 22 --- Loss: 0.2890
# batch 23 --- Loss: 0.3455
# batch 24 --- Loss: 0.2674
# batch 25 --- Loss: 0.1905
# batch 26 --- Loss: 0.1861
# batch 27 --- Loss: 0.2675
# batch 28 --- Loss: 0.2324
# batch 29 --- Loss: 0.1799
# batch 30 --- Loss: 0.2253
# batch 31 --- Loss: 0.1872
# batch 32 --- Loss: 0.2338
# batch 33 --- Loss: 0.1837
# batch 34 --- Loss: 0.2544
# batch 35 --- Loss: 0.1919
# batch 36 --- Loss: 0.1898
# batch 37 --- Loss: 0.2155
# batch 38 --- Loss: 0.2256
# batch 39 --- Loss: 0.2964
# batch 40 --- Loss: 0.1381
# batch 41 --- Loss: 0.2510
# batch 42 --- Loss: 0.2890
# batch 43 --- Loss: 0.2004
# batch 44 --- Loss: 0.1993
# Epoch 32 / 100 --- Loss: 0.2377
# Accuracy: 0.8028 ---- Loss: 0.2311
# batch 0 --- Loss: 0.2335
# batch 1 --- Loss: 0.2519
# batch 2 --- Loss: 0.2340
# batch 3 --- Loss: 0.2734
# batch 4 --- Loss: 0.2381
# batch 5 --- Loss: 0.2284
# batch 6 --- Loss: 0.3260
# batch 7 --- Loss: 0.1995
# batch 8 --- Loss: 0.3772
# batch 9 --- Loss: 0.2191
# batch 10 --- Loss: 0.2651
# batch 11 --- Loss: 0.1951
# batch 12 --- Loss: 0.2735
# batch 13 --- Loss: 0.1760
# batch 14 --- Loss: 0.2117
# batch 15 --- Loss: 0.3470
# batch 16 --- Loss: 0.2565
# batch 17 --- Loss: 0.2675
# batch 18 --- Loss: 0.1847
# batch 19 --- Loss: 0.2248
# batch 20 --- Loss: 0.3079
# batch 21 --- Loss: 0.2069
# batch 22 --- Loss: 0.3679
# batch 23 --- Loss: 0.2781
# batch 24 --- Loss: 0.3781
# batch 25 --- Loss: 0.1971
# batch 26 --- Loss: 0.2321
# batch 27 --- Loss: 0.1587
# batch 28 --- Loss: 0.1993
# batch 29 --- Loss: 0.2806
# batch 30 --- Loss: 0.1805
# batch 31 --- Loss: 0.2091
# batch 32 --- Loss: 0.2036
# batch 33 --- Loss: 0.1958
# batch 34 --- Loss: 0.2045
# batch 35 --- Loss: 0.2536
# batch 36 --- Loss: 0.3125
# batch 37 --- Loss: 0.3126
# batch 38 --- Loss: 0.3580
# batch 39 --- Loss: 0.2098
# batch 40 --- Loss: 0.1841
# batch 41 --- Loss: 0.2021
# batch 42 --- Loss: 0.1622
# batch 43 --- Loss: 0.2051
# batch 44 --- Loss: 0.1862
# Epoch 33 / 100 --- Loss: 0.2438
# Accuracy: 0.7530 ---- Loss: 0.3342
# batch 0 --- Loss: 0.1464
# batch 1 --- Loss: 0.2428
# batch 2 --- Loss: 0.1788
# batch 3 --- Loss: 0.1989
# batch 4 --- Loss: 0.1474
# batch 5 --- Loss: 0.1314
# batch 6 --- Loss: 0.3231
# batch 7 --- Loss: 0.1873
# batch 8 --- Loss: 0.2250
# batch 9 --- Loss: 0.2437
# batch 10 --- Loss: 0.3011
# batch 11 --- Loss: 0.1346
# batch 12 --- Loss: 0.4259
# batch 13 --- Loss: 0.2527
# batch 14 --- Loss: 0.2171
# batch 15 --- Loss: 0.2150
# batch 16 --- Loss: 0.2316
# batch 17 --- Loss: 0.2888
# batch 18 --- Loss: 0.3678
# batch 19 --- Loss: 0.2736
# batch 20 --- Loss: 0.1886
# batch 21 --- Loss: 0.3118
# batch 22 --- Loss: 0.2568
# batch 23 --- Loss: 0.3150
# batch 24 --- Loss: 0.2252
# batch 25 --- Loss: 0.3591
# batch 26 --- Loss: 0.2997
# batch 27 --- Loss: 0.2554
# batch 28 --- Loss: 0.3649
# batch 29 --- Loss: 0.2340
# batch 30 --- Loss: 0.2947
# batch 31 --- Loss: 0.2427
# batch 32 --- Loss: 0.2492
# batch 33 --- Loss: 0.2111
# batch 34 --- Loss: 0.3041
# batch 35 --- Loss: 0.2837
# batch 36 --- Loss: 0.2341
# batch 37 --- Loss: 0.2196
# batch 38 --- Loss: 0.2322
# batch 39 --- Loss: 0.2179
# batch 40 --- Loss: 0.2204
# batch 41 --- Loss: 0.2782
# batch 42 --- Loss: 0.3319
# batch 43 --- Loss: 0.2275
# batch 44 --- Loss: 0.2868
# Epoch 34 / 100 --- Loss: 0.2528
# Accuracy: 0.6887 ---- Loss: 0.2785
# batch 0 --- Loss: 0.1834
# batch 1 --- Loss: 0.2139
# batch 2 --- Loss: 0.2430
# batch 3 --- Loss: 0.2251
# batch 4 --- Loss: 0.2036
# batch 5 --- Loss: 0.3066
# batch 6 --- Loss: 0.1953
# batch 7 --- Loss: 0.2915
# batch 8 --- Loss: 0.2730
# batch 9 --- Loss: 0.2780
# batch 10 --- Loss: 0.2585
# batch 11 --- Loss: 0.1888
# batch 12 --- Loss: 0.2296
# batch 13 --- Loss: 0.3393
# batch 14 --- Loss: 0.2428
# batch 15 --- Loss: 0.2857
# batch 16 --- Loss: 0.1965
# batch 17 --- Loss: 0.1689
# batch 18 --- Loss: 0.3915
# batch 19 --- Loss: 0.1730
# batch 20 --- Loss: 0.2700
# batch 21 --- Loss: 0.3204
# batch 22 --- Loss: 0.3188
# batch 23 --- Loss: 0.2028
# batch 24 --- Loss: 0.2092
# batch 25 --- Loss: 0.2882
# batch 26 --- Loss: 0.2182
# batch 27 --- Loss: 0.2942
# batch 28 --- Loss: 0.2444
# batch 29 --- Loss: 0.2258
# batch 30 --- Loss: 0.2352
# batch 31 --- Loss: 0.1629
# batch 32 --- Loss: 0.2044
# batch 33 --- Loss: 0.2121
# batch 34 --- Loss: 0.1756
# batch 35 --- Loss: 0.2081
# batch 36 --- Loss: 0.2815
# batch 37 --- Loss: 0.2312
# batch 38 --- Loss: 0.1618
# batch 39 --- Loss: 0.2613
# batch 40 --- Loss: 0.4622
# batch 41 --- Loss: 0.2056
# batch 42 --- Loss: 0.5049
# batch 43 --- Loss: 0.3261
# batch 44 --- Loss: 0.1893
# Epoch 35 / 100 --- Loss: 0.2512
# Accuracy: 0.8298 ---- Loss: 0.2066
# batch 0 --- Loss: 0.2227
# batch 1 --- Loss: 0.2856
# batch 2 --- Loss: 0.2739
# batch 3 --- Loss: 0.3397
# batch 4 --- Loss: 0.2241
# batch 5 --- Loss: 0.2026
# batch 6 --- Loss: 0.2901
# batch 7 --- Loss: 0.1840
# batch 8 --- Loss: 0.2272
# batch 9 --- Loss: 0.1720
# batch 10 --- Loss: 0.3427
# batch 11 --- Loss: 0.2121
# batch 12 --- Loss: 0.2327
# batch 13 --- Loss: 0.2232
# batch 14 --- Loss: 0.1837
# batch 15 --- Loss: 0.2074
# batch 16 --- Loss: 0.1850
# batch 17 --- Loss: 0.1690
# batch 18 --- Loss: 0.2501
# batch 19 --- Loss: 0.3422
# batch 20 --- Loss: 0.2786
# batch 21 --- Loss: 0.2117
# batch 22 --- Loss: 0.1890
# batch 23 --- Loss: 0.2703
# batch 24 --- Loss: 0.2691
# batch 25 --- Loss: 0.3674
# batch 26 --- Loss: 0.2036
# batch 27 --- Loss: 0.2331
# batch 28 --- Loss: 0.2097
# batch 29 --- Loss: 0.1694
# batch 30 --- Loss: 0.2596
# batch 31 --- Loss: 0.1739
# batch 32 --- Loss: 0.2587
# batch 33 --- Loss: 0.2284
# batch 34 --- Loss: 0.2247
# batch 35 --- Loss: 0.3451
# batch 36 --- Loss: 0.2749
# batch 37 --- Loss: 0.2384
# batch 38 --- Loss: 0.3424
# batch 39 --- Loss: 0.3216
# batch 40 --- Loss: 0.2708
# batch 41 --- Loss: 0.2816
# batch 42 --- Loss: 0.3031
# batch 43 --- Loss: 0.1891
# batch 44 --- Loss: 0.2712
# Epoch 36 / 100 --- Loss: 0.2479
# Accuracy: 0.6811 ---- Loss: 0.6530
# batch 0 --- Loss: 0.2934
# batch 1 --- Loss: 0.2681
# batch 2 --- Loss: 0.2127
# batch 3 --- Loss: 0.2110
# batch 4 --- Loss: 0.1951
# batch 5 --- Loss: 0.3084
# batch 6 --- Loss: 0.2232
# batch 7 --- Loss: 0.2105
# batch 8 --- Loss: 0.3080
# batch 9 --- Loss: 0.2214
# batch 10 --- Loss: 0.1953
# batch 11 --- Loss: 0.3436
# batch 12 --- Loss: 0.3179
# batch 13 --- Loss: 0.2601
# batch 14 --- Loss: 0.1850
# batch 15 --- Loss: 0.2317
# batch 16 --- Loss: 0.1752
# batch 17 --- Loss: 0.4161
# batch 18 --- Loss: 0.2515
# batch 19 --- Loss: 0.3210
# batch 20 --- Loss: 0.1680
# batch 21 --- Loss: 0.2991
# batch 22 --- Loss: 0.1820
# batch 23 --- Loss: 0.1660
# batch 24 --- Loss: 0.2215
# batch 25 --- Loss: 0.1724
# batch 26 --- Loss: 0.2198
# batch 27 --- Loss: 0.2520
# batch 28 --- Loss: 0.2241
# batch 29 --- Loss: 0.2262
# batch 30 --- Loss: 0.2967
# batch 31 --- Loss: 0.3499
# batch 32 --- Loss: 0.4671
# batch 33 --- Loss: 0.2359
# batch 34 --- Loss: 0.1642
# batch 35 --- Loss: 0.3876
# batch 36 --- Loss: 0.4161
# batch 37 --- Loss: 0.1924
# batch 38 --- Loss: 0.2073
# batch 39 --- Loss: 0.1911
# batch 40 --- Loss: 0.3266
# batch 41 --- Loss: 0.3495
# batch 42 --- Loss: 0.2701
# batch 43 --- Loss: 0.2584
# batch 44 --- Loss: 0.2523
# Epoch 37 / 100 --- Loss: 0.2588
# Accuracy: 0.8268 ---- Loss: 0.2137
# batch 0 --- Loss: 0.3438
# batch 1 --- Loss: 0.2028
# batch 2 --- Loss: 0.2102
# batch 3 --- Loss: 0.2407
# batch 4 --- Loss: 0.1864
# batch 5 --- Loss: 0.2183
# batch 6 --- Loss: 0.3016
# batch 7 --- Loss: 0.4459
# batch 8 --- Loss: 0.3138
# batch 9 --- Loss: 0.4015
# batch 10 --- Loss: 0.2002
# batch 11 --- Loss: 0.2650
# batch 12 --- Loss: 0.2579
# batch 13 --- Loss: 0.2088
# batch 14 --- Loss: 0.2140
# batch 15 --- Loss: 0.2145
# batch 16 --- Loss: 0.3312
# batch 17 --- Loss: 0.2213
# batch 18 --- Loss: 0.2932
# batch 19 --- Loss: 0.2183
# batch 20 --- Loss: 0.3006
# batch 21 --- Loss: 0.2359
# batch 22 --- Loss: 0.4773
# batch 23 --- Loss: 0.1832
# batch 24 --- Loss: 0.2819
# batch 25 --- Loss: 0.2819
# batch 26 --- Loss: 0.1702
# batch 27 --- Loss: 0.3090
# batch 28 --- Loss: 0.2094
# batch 29 --- Loss: 0.1626
# batch 30 --- Loss: 0.1744
# batch 31 --- Loss: 0.1922
# batch 32 --- Loss: 0.2982
# batch 33 --- Loss: 0.2664
# batch 34 --- Loss: 0.2760
# batch 35 --- Loss: 0.2378
# batch 36 --- Loss: 0.3222
# batch 37 --- Loss: 0.2187
# batch 38 --- Loss: 0.2161
# batch 39 --- Loss: 0.2340
# batch 40 --- Loss: 0.1863
# batch 41 --- Loss: 0.1526
# batch 42 --- Loss: 0.2810
# batch 43 --- Loss: 0.2850
# batch 44 --- Loss: 0.1682
# Epoch 38 / 100 --- Loss: 0.2536
# Accuracy: 0.8202 ---- Loss: 0.2066
# batch 0 --- Loss: 0.3806
# batch 1 --- Loss: 0.1989
# batch 2 --- Loss: 0.1961
# batch 3 --- Loss: 0.2685
# batch 4 --- Loss: 0.2397
# batch 5 --- Loss: 0.3095
# batch 6 --- Loss: 0.2657
# batch 7 --- Loss: 0.1746
# batch 8 --- Loss: 0.2132
# batch 9 --- Loss: 0.1727
# batch 10 --- Loss: 0.1720
# batch 11 --- Loss: 0.2961
# batch 12 --- Loss: 0.2189
# batch 13 --- Loss: 0.1773
# batch 14 --- Loss: 0.2987
# batch 15 --- Loss: 0.2645
# batch 16 --- Loss: 0.1633
# batch 17 --- Loss: 0.2209
# batch 18 --- Loss: 0.2702
# batch 19 --- Loss: 0.3296
# batch 20 --- Loss: 0.2470
# batch 21 --- Loss: 0.2821
# batch 22 --- Loss: 0.2604
# batch 23 --- Loss: 0.3711
# batch 24 --- Loss: 0.2381
# batch 25 --- Loss: 0.2756
# batch 26 --- Loss: 0.2860
# batch 27 --- Loss: 0.2190
# batch 28 --- Loss: 0.3173
# batch 29 --- Loss: 0.2565
# batch 30 --- Loss: 0.2667
# batch 31 --- Loss: 0.2322
# batch 32 --- Loss: 0.1842
# batch 33 --- Loss: 0.3466
# batch 34 --- Loss: 0.2150
# batch 35 --- Loss: 0.2228
# batch 36 --- Loss: 0.3172
# batch 37 --- Loss: 0.2432
# batch 38 --- Loss: 0.2153
# batch 39 --- Loss: 0.1562
# batch 40 --- Loss: 0.3094
# batch 41 --- Loss: 0.1758
# batch 42 --- Loss: 0.2337
# batch 43 --- Loss: 0.2017
# batch 44 --- Loss: 0.2308
# Epoch 39 / 100 --- Loss: 0.2474
# Accuracy: 0.8066 ---- Loss: 0.2163
# batch 0 --- Loss: 0.2453
# batch 1 --- Loss: 0.2672
# batch 2 --- Loss: 0.1789
# batch 3 --- Loss: 0.3690
# batch 4 --- Loss: 0.1759
# batch 5 --- Loss: 0.1995
# ...
# Accuracy: 0.4197 ---- Loss: 0.4425
# batch 0 --- Loss: 0.2420
# batch 1 --- Loss: 0.1803
# batch 2 --- Loss: 0.2668
# batch 3 --- Loss: 0.2783
# batch 4 --- Loss: 0.2639
# batch 5 --- Loss: 0.2489
# batch 6 --- Loss: 0.2750
# batch 7 --- Loss: 0.2057
# batch 8 --- Loss: 0.1638
# batch 9 --- Loss: 0.3092
# batch 10 --- Loss: 0.1601
# batch 11 --- Loss: 0.1997
# batch 12 --- Loss: 0.3618
# batch 13 --- Loss: 0.3706
# batch 14 --- Loss: 0.2302
# batch 15 --- Loss: 0.3730
# batch 16 --- Loss: 0.2368
# batch 17 --- Loss: 0.2396
# batch 18 --- Loss: 0.3386
# batch 19 --- Loss: 0.2283
# batch 20 --- Loss: 0.2365
# batch 21 --- Loss: 0.1791
# batch 22 --- Loss: 0.2070
# batch 23 --- Loss: 0.2123
# batch 24 --- Loss: 0.1709
# batch 25 --- Loss: 0.2271
# batch 26 --- Loss: 0.3102
# batch 27 --- Loss: 0.3042
# batch 28 --- Loss: 0.2297
# batch 29 --- Loss: 0.3231
# batch 30 --- Loss: 0.2498
# batch 31 --- Loss: 0.1823
# batch 32 --- Loss: 0.3247
# batch 33 --- Loss: 0.2555
# batch 34 --- Loss: 0.2220
# batch 35 --- Loss: 0.2656
# batch 36 --- Loss: 0.1750
# batch 37 --- Loss: 0.2786
# batch 38 --- Loss: 0.2330
# batch 39 --- Loss: 0.2101
# batch 40 --- Loss: 0.2004
# batch 41 --- Loss: 0.2363
# batch 42 --- Loss: 0.3155
# batch 43 --- Loss: 0.2470
# batch 44 --- Loss: 0.3204
# Epoch 88 / 100 --- Loss: 0.2509
# Accuracy: 0.7158 ---- Loss: 0.2773
# batch 0 --- Loss: 0.1842
# batch 1 --- Loss: 0.1729
# batch 2 --- Loss: 0.3276
# batch 3 --- Loss: 0.2378
# batch 4 --- Loss: 0.4473
# batch 5 --- Loss: 0.2889
# batch 6 --- Loss: 0.2175
# batch 7 --- Loss: 0.3473
# batch 8 --- Loss: 0.3507
# batch 9 --- Loss: 0.1655
# batch 10 --- Loss: 0.4091
# batch 11 --- Loss: 0.3398
# batch 12 --- Loss: 0.2267
# batch 13 --- Loss: 0.1781
# batch 14 --- Loss: 0.2056
# batch 15 --- Loss: 0.2147
# batch 16 --- Loss: 0.2122
# batch 17 --- Loss: 0.2306
# batch 18 --- Loss: 0.2798
# batch 19 --- Loss: 0.2063
# batch 20 --- Loss: 0.2160
# batch 21 --- Loss: 0.1868
# batch 22 --- Loss: 0.1930
# batch 23 --- Loss: 0.1915
# batch 24 --- Loss: 0.2560
# batch 25 --- Loss: 0.2308
# batch 26 --- Loss: 0.2134
# batch 27 --- Loss: 0.2486
# batch 28 --- Loss: 0.1812
# batch 29 --- Loss: 0.2378
# batch 30 --- Loss: 0.2351
# batch 31 --- Loss: 0.3131
# batch 32 --- Loss: 0.2351
# batch 33 --- Loss: 0.2705
# batch 34 --- Loss: 0.1389
# batch 35 --- Loss: 0.1903
# batch 36 --- Loss: 0.2738
# batch 37 --- Loss: 0.2670
# batch 38 --- Loss: 0.1671
# batch 39 --- Loss: 0.2932
# batch 40 --- Loss: 0.2583
# batch 41 --- Loss: 0.1679
# batch 42 --- Loss: 0.2490
# batch 43 --- Loss: 0.1919
# batch 44 --- Loss: 0.3339
# Epoch 89 / 100 --- Loss: 0.2441
# Accuracy: 0.7096 ---- Loss: 0.5500
# batch 0 --- Loss: 0.1863
# batch 1 --- Loss: 0.1697
# batch 2 --- Loss: 0.3777
# batch 3 --- Loss: 0.1769
# batch 4 --- Loss: 0.2447
# batch 5 --- Loss: 0.2933
# batch 6 --- Loss: 0.1648
# batch 7 --- Loss: 0.1777
# batch 8 --- Loss: 0.2109
# batch 9 --- Loss: 0.2324
# batch 10 --- Loss: 0.2202
# batch 11 --- Loss: 0.2638
# batch 12 --- Loss: 0.3303
# batch 13 --- Loss: 0.3280
# batch 14 --- Loss: 0.3011
# batch 15 --- Loss: 0.2178
# batch 16 --- Loss: 0.2568
# batch 17 --- Loss: 0.2294
# batch 18 --- Loss: 0.1869
# batch 19 --- Loss: 0.1815
# batch 20 --- Loss: 0.2105
# batch 21 --- Loss: 0.1898
# batch 22 --- Loss: 0.3052
# batch 23 --- Loss: 0.2674
# batch 24 --- Loss: 0.1577
# batch 25 --- Loss: 0.2540
# batch 26 --- Loss: 0.3501
# batch 27 --- Loss: 0.1872
# batch 28 --- Loss: 0.2978
# batch 29 --- Loss: 0.2511
# batch 30 --- Loss: 0.3259
# batch 31 --- Loss: 0.1704
# batch 32 --- Loss: 0.2252
# batch 33 --- Loss: 0.1935
# batch 34 --- Loss: 0.3992
# batch 35 --- Loss: 0.2229
# batch 36 --- Loss: 0.1919
# batch 37 --- Loss: 0.2327
# batch 38 --- Loss: 0.3200
# batch 39 --- Loss: 0.3650
# batch 40 --- Loss: 0.3684
# batch 41 --- Loss: 0.1758
# batch 42 --- Loss: 0.2668
# batch 43 --- Loss: 0.2480
# batch 44 --- Loss: 0.1822
# Epoch 90 / 100 --- Loss: 0.2469
# Accuracy: 0.6565 ---- Loss: 0.3122
# batch 0 --- Loss: 0.2314
# batch 1 --- Loss: 0.2085
# batch 2 --- Loss: 0.2628
# batch 3 --- Loss: 0.1889
# batch 4 --- Loss: 0.1846
# batch 5 --- Loss: 0.2450
# batch 6 --- Loss: 0.2231
# batch 7 --- Loss: 0.2360
# batch 8 --- Loss: 0.2743
# batch 9 --- Loss: 0.1726
# batch 10 --- Loss: 0.2637
# batch 11 --- Loss: 0.2617
# batch 12 --- Loss: 0.2556
# batch 13 --- Loss: 0.2242
# batch 14 --- Loss: 0.3436
# batch 15 --- Loss: 0.1966
# batch 16 --- Loss: 0.2211
# batch 17 --- Loss: 0.2152
# batch 18 --- Loss: 0.1777
# batch 19 --- Loss: 0.3895
# batch 20 --- Loss: 0.2361
# batch 21 --- Loss: 0.3464
# batch 22 --- Loss: 0.2456
# batch 23 --- Loss: 0.2021
# batch 24 --- Loss: 0.2263
# batch 25 --- Loss: 0.2234
# batch 26 --- Loss: 0.1546
# batch 27 --- Loss: 0.2114
# batch 28 --- Loss: 0.2668
# batch 29 --- Loss: 0.2087
# batch 30 --- Loss: 0.2636
# batch 31 --- Loss: 0.2764
# batch 32 --- Loss: 0.1832
# batch 33 --- Loss: 0.2945
# batch 34 --- Loss: 0.1809
# batch 35 --- Loss: 0.1747
# batch 36 --- Loss: 0.2050
# batch 37 --- Loss: 0.1969
# batch 38 --- Loss: 0.3311
# batch 39 --- Loss: 0.4966
# batch 40 --- Loss: 0.2398
# batch 41 --- Loss: 0.4153
# batch 42 --- Loss: 0.2874
# batch 43 --- Loss: 0.2471
# batch 44 --- Loss: 0.2899
# Epoch 91 / 100 --- Loss: 0.2484
# Accuracy: 0.8147 ---- Loss: 0.2164
# batch 0 --- Loss: 0.1938
# batch 1 --- Loss: 0.3051
# batch 2 --- Loss: 0.1938
# batch 3 --- Loss: 0.2331
# batch 4 --- Loss: 0.3242
# batch 5 --- Loss: 0.3267
# batch 6 --- Loss: 0.2079
# batch 7 --- Loss: 0.2829
# batch 8 --- Loss: 0.2067
# batch 9 --- Loss: 0.1893
# batch 10 --- Loss: 0.2093
# batch 11 --- Loss: 0.2112
# batch 12 --- Loss: 0.2911
# batch 13 --- Loss: 0.2855
# batch 14 --- Loss: 0.2309
# batch 15 --- Loss: 0.2042
# batch 16 --- Loss: 0.2511
# batch 17 --- Loss: 0.2943
# batch 18 --- Loss: 0.2594
# batch 19 --- Loss: 0.2756
# batch 20 --- Loss: 0.1738
# batch 21 --- Loss: 0.1738
# batch 22 --- Loss: 0.3514
# batch 23 --- Loss: 0.1644
# batch 24 --- Loss: 0.2547
# batch 25 --- Loss: 0.2085
# batch 26 --- Loss: 0.2407
# batch 27 --- Loss: 0.2438
# batch 28 --- Loss: 0.2662
# batch 29 --- Loss: 0.1706
# batch 30 --- Loss: 0.1995
# batch 31 --- Loss: 0.2424
# batch 32 --- Loss: 0.2515
# batch 33 --- Loss: 0.2737
# batch 34 --- Loss: 0.1810
# batch 35 --- Loss: 0.2024
# batch 36 --- Loss: 0.1748
# batch 37 --- Loss: 0.2006
# batch 38 --- Loss: 0.2262
# batch 39 --- Loss: 0.1648
# batch 40 --- Loss: 0.1691
# batch 41 --- Loss: 0.3051
# batch 42 --- Loss: 0.3436
# batch 43 --- Loss: 0.2401
# batch 44 --- Loss: 0.1934
# Epoch 92 / 100 --- Loss: 0.2354
# Accuracy: 0.8062 ---- Loss: 0.2504
# batch 0 --- Loss: 0.2095
# batch 1 --- Loss: 0.1787
# batch 2 --- Loss: 0.1359
# batch 3 --- Loss: 0.3327
# batch 4 --- Loss: 0.2668
# batch 5 --- Loss: 0.2725
# batch 6 --- Loss: 0.2666
# batch 7 --- Loss: 0.3387
# batch 8 --- Loss: 0.2032
# batch 9 --- Loss: 0.1816
# batch 10 --- Loss: 0.1844
# batch 11 --- Loss: 0.3506
# batch 12 --- Loss: 0.2867
# batch 13 --- Loss: 0.2108
# batch 14 --- Loss: 0.2745
# batch 15 --- Loss: 0.2155
# batch 16 --- Loss: 0.3292
# batch 17 --- Loss: 0.1782
# batch 18 --- Loss: 0.2601
# batch 19 --- Loss: 0.1743
# batch 20 --- Loss: 0.2380
# batch 21 --- Loss: 0.2654
# batch 22 --- Loss: 0.3054
# batch 23 --- Loss: 0.2252
# batch 24 --- Loss: 0.3380
# batch 25 --- Loss: 0.2476
# batch 26 --- Loss: 0.2478
# batch 27 --- Loss: 0.3520
# batch 28 --- Loss: 0.3232
# batch 29 --- Loss: 0.2312
# batch 30 --- Loss: 0.2342
# batch 31 --- Loss: 0.1839
# batch 32 --- Loss: 0.1947
# batch 33 --- Loss: 0.2069
# batch 34 --- Loss: 0.2494
# batch 35 --- Loss: 0.2286
# batch 36 --- Loss: 0.1932
# batch 37 --- Loss: 0.3362
# batch 38 --- Loss: 0.1952
# batch 39 --- Loss: 0.2963
# batch 40 --- Loss: 0.1991
# batch 41 --- Loss: 0.2124
# batch 42 --- Loss: 0.2436
# batch 43 --- Loss: 0.2329
# batch 44 --- Loss: 0.2451
# Epoch 93 / 100 --- Loss: 0.2461
# Accuracy: 0.8229 ---- Loss: 0.2184
# batch 0 --- Loss: 0.2256
# batch 1 --- Loss: 0.2573
# batch 2 --- Loss: 0.1928
# batch 3 --- Loss: 0.1727
# batch 4 --- Loss: 0.3587
# batch 5 --- Loss: 0.1716
# batch 6 --- Loss: 0.2136
# batch 7 --- Loss: 0.2411
# batch 8 --- Loss: 0.2263
# batch 9 --- Loss: 0.1713
# batch 10 --- Loss: 0.2125
# batch 11 --- Loss: 0.1795
# batch 12 --- Loss: 0.2865
# batch 13 --- Loss: 0.1837
# batch 14 --- Loss: 0.2802
# batch 15 --- Loss: 0.3776
# batch 16 --- Loss: 0.2872
# batch 17 --- Loss: 0.2244
# batch 18 --- Loss: 0.1932
# batch 19 --- Loss: 0.2651
# batch 20 --- Loss: 0.2618
# batch 21 --- Loss: 0.2262
# batch 22 --- Loss: 0.2764
# batch 23 --- Loss: 0.1566
# batch 24 --- Loss: 0.2218
# batch 25 --- Loss: 0.3095
# batch 26 --- Loss: 0.3685
# batch 27 --- Loss: 0.1614
# batch 28 --- Loss: 0.3135
# batch 29 --- Loss: 0.2431
# batch 30 --- Loss: 0.2041
# batch 31 --- Loss: 0.1724
# batch 32 --- Loss: 0.2390
# batch 33 --- Loss: 0.2295
# batch 34 --- Loss: 0.4019
# batch 35 --- Loss: 0.2808
# batch 36 --- Loss: 0.2670
# batch 37 --- Loss: 0.2342
# batch 38 --- Loss: 0.2591
# batch 39 --- Loss: 0.4366
# batch 40 --- Loss: 0.1996
# batch 41 --- Loss: 0.2571
# batch 42 --- Loss: 0.2761
# batch 43 --- Loss: 0.2343
# batch 44 --- Loss: 0.2324
# Epoch 94 / 100 --- Loss: 0.2485
# Accuracy: 0.8250 ---- Loss: 0.2135
# batch 0 --- Loss: 0.4171
# batch 1 --- Loss: 0.3306
# batch 2 --- Loss: 0.1962
# batch 3 --- Loss: 0.1868
# batch 4 --- Loss: 0.1764
# batch 5 --- Loss: 0.2262
# batch 6 --- Loss: 0.1654
# batch 7 --- Loss: 0.2643
# batch 8 --- Loss: 0.2175
# batch 9 --- Loss: 0.2141
# batch 10 --- Loss: 0.2315
# batch 11 --- Loss: 0.2105
# batch 12 --- Loss: 0.2711
# batch 13 --- Loss: 0.2419
# batch 14 --- Loss: 0.2915
# batch 15 --- Loss: 0.2236
# batch 16 --- Loss: 0.2469
# batch 17 --- Loss: 0.1793
# batch 18 --- Loss: 0.3492
# batch 19 --- Loss: 0.2053
# batch 20 --- Loss: 0.2345
# batch 21 --- Loss: 0.2512
# batch 22 --- Loss: 0.2511
# batch 23 --- Loss: 0.2925
# batch 24 --- Loss: 0.3434
# batch 25 --- Loss: 0.1778
# batch 26 --- Loss: 0.2502
# batch 27 --- Loss: 0.2162
# batch 28 --- Loss: 0.3909
# batch 29 --- Loss: 0.3728
# batch 30 --- Loss: 0.3251
# batch 31 --- Loss: 0.2597
# batch 32 --- Loss: 0.2667
# batch 33 --- Loss: 0.2169
# batch 34 --- Loss: 0.1808
# batch 35 --- Loss: 0.2992
# batch 36 --- Loss: 0.3048
# batch 37 --- Loss: 0.1678
# batch 38 --- Loss: 0.2341
# batch 39 --- Loss: 0.1614
# batch 40 --- Loss: 0.2115
# batch 41 --- Loss: 0.2767
# batch 42 --- Loss: 0.2097
# batch 43 --- Loss: 0.1664
# batch 44 --- Loss: 0.1852
# Epoch 95 / 100 --- Loss: 0.2465
# Accuracy: 0.8125 ---- Loss: 0.2181
# batch 0 --- Loss: 0.3282
# batch 1 --- Loss: 0.2688
# batch 2 --- Loss: 0.2033
# batch 3 --- Loss: 0.2629
# batch 4 --- Loss: 0.1964
# batch 5 --- Loss: 0.2794
# batch 6 --- Loss: 0.2562
# batch 7 --- Loss: 0.2273
# batch 8 --- Loss: 0.1664
# batch 9 --- Loss: 0.2135
# batch 10 --- Loss: 0.2928
# batch 11 --- Loss: 0.2113
# batch 12 --- Loss: 0.2503
# batch 13 --- Loss: 0.3593
# batch 14 --- Loss: 0.3136
# batch 15 --- Loss: 0.2522
# batch 16 --- Loss: 0.1979
# batch 17 --- Loss: 0.1742
# batch 18 --- Loss: 0.1475
# batch 19 --- Loss: 0.1838
# batch 20 --- Loss: 0.2264
# batch 21 --- Loss: 0.3016
# batch 22 --- Loss: 0.2620
# batch 23 --- Loss: 0.2797
# batch 24 --- Loss: 0.1621
# batch 25 --- Loss: 0.2248
# batch 26 --- Loss: 0.1877
# batch 27 --- Loss: 0.4042
# batch 28 --- Loss: 0.3025
# batch 29 --- Loss: 0.2391
# batch 30 --- Loss: 0.2581
# batch 31 --- Loss: 0.2810
# batch 32 --- Loss: 0.2406
# batch 33 --- Loss: 0.4894
# batch 34 --- Loss: 0.1955
# batch 35 --- Loss: 0.3222
# batch 36 --- Loss: 0.1640
# batch 37 --- Loss: 0.1847
# batch 38 --- Loss: 0.3596
# batch 39 --- Loss: 0.1757
# batch 40 --- Loss: 0.2437
# batch 41 --- Loss: 0.2175
# batch 42 --- Loss: 0.1482
# batch 43 --- Loss: 0.1665
# batch 44 --- Loss: 0.2007
# Epoch 96 / 100 --- Loss: 0.2450
# Accuracy: 0.8125 ---- Loss: 0.2226
# batch 0 --- Loss: 0.2146
# batch 1 --- Loss: 0.2943
# batch 2 --- Loss: 0.2727
# batch 3 --- Loss: 0.3085
# batch 4 --- Loss: 0.3786
# batch 5 --- Loss: 0.1866
# batch 6 --- Loss: 0.2380
# batch 7 --- Loss: 0.3044
# batch 8 --- Loss: 0.2989
# batch 9 --- Loss: 0.2105
# batch 10 --- Loss: 0.2522
# batch 11 --- Loss: 0.2649
# batch 12 --- Loss: 0.3266
# batch 13 --- Loss: 0.1793
# batch 14 --- Loss: 0.1857
# batch 15 --- Loss: 0.3003
# batch 16 --- Loss: 0.3313
# batch 17 --- Loss: 0.2367
# batch 18 --- Loss: 0.2955
# batch 19 --- Loss: 0.2200
# batch 20 --- Loss: 0.2767
# batch 21 --- Loss: 0.3626
# batch 22 --- Loss: 0.3126
# batch 23 --- Loss: 0.2112
# batch 24 --- Loss: 0.1683
# batch 25 --- Loss: 0.1581
# batch 26 --- Loss: 0.2677
# batch 27 --- Loss: 0.2176
# batch 28 --- Loss: 0.2182
# batch 29 --- Loss: 0.1750
# batch 30 --- Loss: 0.1630
# batch 31 --- Loss: 0.1726
# batch 32 --- Loss: 0.2121
# batch 33 --- Loss: 0.2994
# batch 34 --- Loss: 0.2935
# batch 35 --- Loss: 0.3240
# batch 36 --- Loss: 0.1657
# batch 37 --- Loss: 0.2984
# batch 38 --- Loss: 0.2689
# batch 39 --- Loss: 0.2188
# batch 40 --- Loss: 0.2382
# batch 41 --- Loss: 0.3814
# batch 42 --- Loss: 0.2764
# batch 43 --- Loss: 0.2938
# batch 44 --- Loss: 0.2455
# Epoch 97 / 100 --- Loss: 0.2560
# Accuracy: 0.8278 ---- Loss: 0.2049
# batch 0 --- Loss: 0.3764
# batch 1 --- Loss: 0.3358
# batch 2 --- Loss: 0.4601
# batch 3 --- Loss: 0.2551
# batch 4 --- Loss: 0.2613
# batch 5 --- Loss: 0.3386
# batch 6 --- Loss: 0.3240
# batch 7 --- Loss: 0.2244
# batch 8 --- Loss: 0.3062
# batch 9 --- Loss: 0.2094
# batch 10 --- Loss: 0.1661
# batch 11 --- Loss: 0.1838
# batch 12 --- Loss: 0.2202
# batch 13 --- Loss: 0.3532
# batch 14 --- Loss: 0.2160
# batch 15 --- Loss: 0.1868
# batch 16 --- Loss: 0.2259
# batch 17 --- Loss: 0.2512
# batch 18 --- Loss: 0.1765
# batch 19 --- Loss: 0.1916
# batch 20 --- Loss: 0.1957
# batch 21 --- Loss: 0.2049
# batch 22 --- Loss: 0.3336
# batch 23 --- Loss: 0.4529
# batch 24 --- Loss: 0.1975
# batch 25 --- Loss: 0.2640
# batch 26 --- Loss: 0.2524
# batch 27 --- Loss: 0.3204
# batch 28 --- Loss: 0.1900
# batch 29 --- Loss: 0.2403
# batch 30 --- Loss: 0.3318
# batch 31 --- Loss: 0.2885
# batch 32 --- Loss: 0.3239
# batch 33 --- Loss: 0.2003
# batch 34 --- Loss: 0.2096
# batch 35 --- Loss: 0.2207
# batch 36 --- Loss: 0.2821
# batch 37 --- Loss: 0.1833
# batch 38 --- Loss: 0.2561
# batch 39 --- Loss: 0.2908
# batch 40 --- Loss: 0.2676
# batch 41 --- Loss: 0.3114
# batch 42 --- Loss: 0.1882
# batch 43 --- Loss: 0.2043
# batch 44 --- Loss: 0.2271
# Epoch 98 / 100 --- Loss: 0.2600
# Accuracy: 0.8317 ---- Loss: 0.2074
# batch 0 --- Loss: 0.1733
# batch 1 --- Loss: 0.2196
# batch 2 --- Loss: 0.2809
# batch 3 --- Loss: 0.2287
# batch 4 --- Loss: 0.2002
# batch 5 --- Loss: 0.2105
# batch 6 --- Loss: 0.3313
# batch 7 --- Loss: 0.2799
# batch 8 --- Loss: 0.2479
# batch 9 --- Loss: 0.1868
# batch 10 --- Loss: 0.2674
# batch 11 --- Loss: 0.2839
# batch 12 --- Loss: 0.3580
# batch 13 --- Loss: 0.2461
# batch 14 --- Loss: 0.2432
# batch 15 --- Loss: 0.2025
# batch 16 --- Loss: 0.2622
# batch 17 --- Loss: 0.2639
# batch 18 --- Loss: 0.2919
# batch 19 --- Loss: 0.1855
# batch 20 --- Loss: 0.1869
# batch 21 --- Loss: 0.1990
# batch 22 --- Loss: 0.2151
# batch 23 --- Loss: 0.1381
# batch 24 --- Loss: 0.2178
# batch 25 --- Loss: 0.2761
# batch 26 --- Loss: 0.2540
# batch 27 --- Loss: 0.1935
# batch 28 --- Loss: 0.2790
# batch 29 --- Loss: 0.2957
# batch 30 --- Loss: 0.2714
# batch 31 --- Loss: 0.2369
# batch 32 --- Loss: 0.3286
# batch 33 --- Loss: 0.2579
# batch 34 --- Loss: 0.3018
# batch 35 --- Loss: 0.3596
# batch 36 --- Loss: 0.2441
# batch 37 --- Loss: 0.1934
# batch 38 --- Loss: 0.2415
# batch 39 --- Loss: 0.3157
# batch 40 --- Loss: 0.2628
# batch 41 --- Loss: 0.2236
# batch 42 --- Loss: 0.1786
# batch 43 --- Loss: 0.1934
# batch 44 --- Loss: 0.2485
# Epoch 99 / 100 --- Loss: 0.2461
# Accuracy: 0.8316 ---- Loss: 0.2080
# batch 0 --- Loss: 0.2241
# batch 1 --- Loss: 0.2308
# batch 2 --- Loss: 0.2387
# batch 3 --- Loss: 0.1812
# batch 4 --- Loss: 0.1917
# batch 5 --- Loss: 0.2733
# batch 6 --- Loss: 0.1929
# batch 7 --- Loss: 0.2627
# batch 8 --- Loss: 0.1834
# batch 9 --- Loss: 0.2294
# batch 10 --- Loss: 0.2246
# batch 11 --- Loss: 0.2206
# batch 12 --- Loss: 0.1917
# batch 13 --- Loss: 0.2040
# batch 14 --- Loss: 0.2294
# batch 15 --- Loss: 0.2581
# batch 16 --- Loss: 0.1725
# batch 17 --- Loss: 0.2739
# batch 18 --- Loss: 0.2768
# batch 19 --- Loss: 0.2617
# batch 20 --- Loss: 0.1494
# batch 21 --- Loss: 0.4606
# batch 22 --- Loss: 0.3025
# batch 23 --- Loss: 0.1841
# batch 24 --- Loss: 0.3120
# batch 25 --- Loss: 0.3552
# batch 26 --- Loss: 0.3746
# batch 27 --- Loss: 0.2074
# batch 28 --- Loss: 0.3866
# batch 29 --- Loss: 0.2050
# batch 30 --- Loss: 0.1626
# batch 31 --- Loss: 0.3089
# batch 32 --- Loss: 0.3429
# batch 33 --- Loss: 0.3107
# batch 34 --- Loss: 0.2818
# batch 35 --- Loss: 0.2521
# batch 36 --- Loss: 0.2042
# batch 37 --- Loss: 0.2664
# batch 38 --- Loss: 0.3329
# batch 39 --- Loss: 0.3389
# batch 40 --- Loss: 0.1981
# batch 41 --- Loss: 0.2045
# batch 42 --- Loss: 0.1615
# batch 43 --- Loss: 0.2336
# batch 44 --- Loss: 0.2094
# Epoch 100 / 100 --- Loss: 0.2504
# Accuracy: 0.7970 ---- Loss: 0.2392
# []

# %% [markdown]
# ### Testing and Visualization

# %%
model.eval()

output_masks = []
output_labels = []

def Threshold(label, output):
    pass

with torch.no_grad():
    for i in range(testset.__len__()):
        image, labels = testset.__getitem__(i)
    
        input_image = image.unsqueeze(0).to(device)
        pred = model(input_image)

        output_mask = torch.max(pred, dim = 1)[1].cpu().squeeze(0).numpy()#.astype(np.float32)

        labels = labels[0]
        crop_x = (labels.shape[0] - output_mask.shape[0]) // 2
        crop_y = (labels.shape[1] - output_mask.shape[1]) // 2
        labels = labels[crop_x: labels.shape[0] - crop_x, crop_y: labels.shape[1] - crop_y].numpy()
    
        output_masks.append(output_mask)
        output_labels.append(labels)

# %%
fig, axes = plt.subplots(testset.__len__(), 2, figsize = (10, 70))

for i in range(testset.__len__()):
    axes[i, 0].imshow(output_labels[i],cmap='gray')
    axes[i, 0].axis('off')
    axes[i, 1].imshow(output_masks[i],cmap='gray')
    axes[i, 1].axis('off')
